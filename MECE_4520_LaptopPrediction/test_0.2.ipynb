# %% [markdown]
# <a href="https://colab.research.google.com/github/zw2788/MECE4520_project/blob/main/MECE_4520_LaptopPrediction/test_0.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Neural Network

# %%
from typing import Tuple
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set(font_scale=1.5)
sns.set_style("whitegrid", {'grid.linestyle':'--'})

import numpy as np
import pandas as pd

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/Laptop_Intel1012.csv")
data.head()
# Out:
#    laptop_ID Company             Product            TypeName  Inches  \
# 0        739    Dell       Inspiron 3567            Notebook    15.6
# 1        898    Asus  Rog GL753VD-GC082T              Gaming    17.3
# 2         45    Dell       Inspiron 7773  2 in 1 Convertible    17.3
# 3        399    Acer            Aspire 5            Notebook    15.6
# 4        476  Lenovo      Thinkpad T460s           Ultrabook    14.0
#
#                   ScreenResolution                          Cpu  \
# 0                         1366x768   Intel Core i5 7200U 2.5GHz
# 1                Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz
# 2  Full HD / Touchscreen 1920x1080   Intel Core i5 8250U 1.6GHz
# 3               IPS Panel 1366x768   Intel Core i5 8250U 1.6GHz
# 4     IPS Panel Quad HD+ 2560x1440   Intel Core i7 6600U 2.6GHz
#
#    CPU_benchmark   Ram  Ram_benchmark               Memory  Memory_benchmark  \
# 0           3397  12GB             12              1TB HDD             39.99
# 1           5092  12GB             12  128GB SSD + 1TB HDD             58.98
# 2           5901  12GB             12              1TB HDD             39.99
# 3           5901  12GB             12              1TB HDD             39.99
# 4           3474  12GB             12            256GB SSD             22.99
#
#                       Gpu  GPU_benchmark       OpSys  Weight  \
# 0   Intel HD Graphics 520            3.5  Windows 10   2.3kg
# 1      AMD Radeon R5 M430            3.1  Windows 10  1.90kg
# 2   Intel HD Graphics 520            3.5  Windows 10  1.86kg
# 3   Intel HD Graphics 520            3.5  Windows 10   1.2kg
# 4  Intel HD Graphics 6000            3.9       macOS  1.34kg
#
#    Weight_benchmark  Price_euros
# 0              2.30       418.64
# 1              1.90       817.95
# 2              1.86       469.00
# 3              1.20      1535.00
# 4              1.34       898.94

# %%
# We can choose the features needed here
features = [
    "GPU_benchmark",
    "Memory_benchmark",
    "CPU_benchmark",
    "Weight_benchmark",
    "Ram_benchmark"

]
label = "Price_euros"

# train test split
X_raw, X_raw_test, Y, Y_test = train_test_split(data[features].values, data[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw)
X = scaler.transform(X_raw)
X_test = scaler.transform(X_raw_test)

# formatting
Y = Y.reshape((-1, 1))
Y_test = Y_test.reshape((-1, 1))

# %%
fig = plt.figure(figsize=(16,6))
axes = fig.add_subplot(1, 1, 1)
axes.plot(X, Y, 'ro')
axes.set_xlabel('x')
axes.set_ylabel('u_ture')
axes.grid()

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam


model=Sequential([
    Dense(units=50,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=20,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history = model.fit(
    x=X,
    y=Y,
    batch_size=32,
    epochs=20,
    validation_data=(X_test, Y_test),
    verbose=1,
    shuffle=True,
)
# Out:
# Epoch 1/20
# 26/26 [==============================] - 1s 9ms/step - loss: 1723056.7500 - mse: 1723056.7500 - val_loss: 1791956.1250 - val_mse: 1791956.1250
# Epoch 2/20
# 26/26 [==============================] - 0s 4ms/step - loss: 1554383.6250 - mse: 1554383.6250 - val_loss: 1218108.3750 - val_mse: 1218108.3750
# Epoch 3/20
# 26/26 [==============================] - 0s 4ms/step - loss: 601297.2500 - mse: 601297.2500 - val_loss: 428450.9688 - val_mse: 428450.9688
# Epoch 4/20
# 26/26 [==============================] - 0s 4ms/step - loss: 275425.9688 - mse: 275425.9688 - val_loss: 278571.6562 - val_mse: 278571.6562
# Epoch 5/20
# 26/26 [==============================] - 0s 5ms/step - loss: 228664.7969 - mse: 228664.7969 - val_loss: 245477.8750 - val_mse: 245477.8750
# Epoch 6/20
# 26/26 [==============================] - 0s 4ms/step - loss: 208975.4688 - mse: 208975.4688 - val_loss: 227576.5156 - val_mse: 227576.5156
# Epoch 7/20
# 26/26 [==============================] - 0s 4ms/step - loss: 197311.8438 - mse: 197311.8438 - val_loss: 212056.3750 - val_mse: 212056.3750
# Epoch 8/20
# 26/26 [==============================] - 0s 4ms/step - loss: 191811.2812 - mse: 191811.2812 - val_loss: 203161.3125 - val_mse: 203161.3125
# Epoch 9/20
# 26/26 [==============================] - 0s 4ms/step - loss: 187484.7031 - mse: 187484.7031 - val_loss: 200940.8594 - val_mse: 200940.8594
# Epoch 10/20
# 26/26 [==============================] - 0s 4ms/step - loss: 185826.4062 - mse: 185826.4062 - val_loss: 196568.3281 - val_mse: 196568.3281
# Epoch 11/20
# 26/26 [==============================] - 0s 4ms/step - loss: 185824.9219 - mse: 185824.9219 - val_loss: 192964.8125 - val_mse: 192964.8125
# Epoch 12/20
# 26/26 [==============================] - 0s 4ms/step - loss: 182638.8594 - mse: 182638.8594 - val_loss: 193490.7812 - val_mse: 193490.7812
# Epoch 13/20
# 26/26 [==============================] - 0s 5ms/step - loss: 181463.0469 - mse: 181463.0469 - val_loss: 189960.9688 - val_mse: 189960.9688
# Epoch 14/20
# 26/26 [==============================] - 0s 4ms/step - loss: 181159.8906 - mse: 181159.8906 - val_loss: 192804.8125 - val_mse: 192804.8125
# Epoch 15/20
# 26/26 [==============================] - 0s 4ms/step - loss: 182719.8438 - mse: 182719.8438 - val_loss: 187943.1562 - val_mse: 187943.1562
# Epoch 16/20
# 26/26 [==============================] - 0s 4ms/step - loss: 187560.4844 - mse: 187560.4844 - val_loss: 190642.4062 - val_mse: 190642.4062
# Epoch 17/20
# 26/26 [==============================] - 0s 3ms/step - loss: 180543.3594 - mse: 180543.3594 - val_loss: 188694.2031 - val_mse: 188694.2031
# Epoch 18/20
# 26/26 [==============================] - 0s 4ms/step - loss: 180361.0156 - mse: 180361.0156 - val_loss: 195698.0156 - val_mse: 195698.0156
# Epoch 19/20
# 26/26 [==============================] - 0s 3ms/step - loss: 178853.9375 - mse: 178853.9375 - val_loss: 187262.8125 - val_mse: 187262.8125
# Epoch 20/20
# 26/26 [==============================] - 0s 3ms/step - loss: 179114.9375 - mse: 179114.9375 - val_loss: 190745.4219 - val_mse: 190745.4219

# %%
def plot_history(history, key):
  plt.plot(history.history[key])
  plt.plot(history.history['val_'+key])
  plt.xlabel("Epochs")
  plt.ylabel(key)
  plt.legend([key, 'val_'+key])
  plt.show()
# Plot the history
plot_history(history, 'mse')

# %%
yhat= model.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 3ms/step

# %%
r2 = np.power(yhat - np.mean(Y_test), 2).sum() / np.power(Y_test - np.mean(Y_test), 2).sum()
r2
# Out:
# 0.7031391123742977

# %% [markdown]
# GPU_NV

# %%
GPU_NV=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/NV.csv")
GPU_NV.head()
# Out:
#    laptop_ID Company             Product TypeName  Inches  \
# 0        151     MSI         GE72MVR 7RG   Gaming    17.3
# 1       1232    Asus           ROG Strix   Gaming    17.3
# 2       1251     MSI       GE72VR Apache   Gaming    17.3
# 3        306    Asus  Rog GL702VS-GC095T   Gaming    17.3
# 4        584  Lenovo  IdeaPad Y910-17ISK   Gaming    17.3
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 1            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 2            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 4  IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz           6933
#
#     Ram               Memory  Memory_benchmark                   Gpu  \
# 0  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 1  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 2  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 3  16GB  256GB SSD + 1TB HDD             69.98    Nvidia GeForce 920
# 4  32GB  256GB SSD + 1TB HDD             69.98   Nvidia GeForce 920M
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            6.5  Windows 10   2.1kg      1145.00
# 1            6.5  Windows 10  2.77kg       999.00
# 2            6.5  Windows 10  2.77kg      1549.00
# 3            3.6       Linux   2.1kg       519.00
# 4            3.6  Windows 10   2.2kg       720.32

# %%
features_GPU_NV = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_NV, X_raw_test_GPU_NV, Y_GPU_NV, Y_test_GPU_NV = train_test_split(GPU_NV[features_GPU_NV].values, GPU_NV[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_NV)
X_GPU_NV = scaler.transform(X_raw_GPU_NV)
X_test_GPU_NV = scaler.transform(X_raw_test_GPU_NV)

# formatting
Y_GPU_NV = Y_GPU_NV.reshape((-1, 1))
Y_test_GPU_NV = Y_test_GPU_NV.reshape((-1, 1))

model_GPU_NV=Sequential([
    Dense(units=25,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=15,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_NV.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_NV = model_GPU_NV.fit(
    x=X_GPU_NV,
    y=Y_GPU_NV,
    batch_size=16,
    epochs=20,
    validation_data=(X_test_GPU_NV, Y_test_GPU_NV),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_NV, 'mse')
yhat_GPU_NV= model_GPU_NV.predict(X_test_GPU_NV)

r2_GPU_NV = np.power(yhat_GPU_NV - np.mean(Y_test_GPU_NV), 2).sum() / np.power(Y_test_GPU_NV - np.mean(Y_test_GPU_NV), 2).sum()
r2_GPU_NV
# Out:
# Epoch 1/20
# 14/14 [==============================] - 1s 15ms/step - loss: 2971144.7500 - mse: 2971144.7500 - val_loss: 3216420.0000 - val_mse: 3216420.0000
# Epoch 2/20
# 14/14 [==============================] - 0s 5ms/step - loss: 2965431.5000 - mse: 2965431.5000 - val_loss: 3199795.5000 - val_mse: 3199795.5000
# Epoch 3/20
# 14/14 [==============================] - 0s 6ms/step - loss: 2920853.0000 - mse: 2920853.0000 - val_loss: 3099280.0000 - val_mse: 3099280.0000
# Epoch 4/20
# 14/14 [==============================] - 0s 4ms/step - loss: 2715556.2500 - mse: 2715556.2500 - val_loss: 2721108.0000 - val_mse: 2721108.0000
# Epoch 5/20
# 14/14 [==============================] - 0s 6ms/step - loss: 2114557.0000 - mse: 2114557.0000 - val_loss: 1772995.6250 - val_mse: 1772995.6250
# Epoch 6/20
# 14/14 [==============================] - 0s 4ms/step - loss: 992317.0625 - mse: 992317.0625 - val_loss: 549795.8125 - val_mse: 549795.8125
# Epoch 7/20
# 14/14 [==============================] - 0s 4ms/step - loss: 308244.4375 - mse: 308244.4375 - val_loss: 334038.3125 - val_mse: 334038.3125
# Epoch 8/20
# 14/14 [==============================] - 0s 5ms/step - loss: 304999.8750 - mse: 304999.8750 - val_loss: 308840.9688 - val_mse: 308840.9688
# Epoch 9/20
# 14/14 [==============================] - 0s 4ms/step - loss: 279571.3750 - mse: 279571.3750 - val_loss: 335340.0625 - val_mse: 335340.0625
# Epoch 10/20
# 14/14 [==============================] - 0s 4ms/step - loss: 280673.3125 - mse: 280673.3125 - val_loss: 312019.1875 - val_mse: 312019.1875
# Epoch 11/20
# 14/14 [==============================] - 0s 5ms/step - loss: 272056.8125 - mse: 272056.8125 - val_loss: 327992.1562 - val_mse: 327992.1562
# Epoch 12/20
# 14/14 [==============================] - 0s 5ms/step - loss: 271103.7188 - mse: 271103.7188 - val_loss: 322535.6250 - val_mse: 322535.6250
# Epoch 13/20
# 14/14 [==============================] - 0s 5ms/step - loss: 272429.8750 - mse: 272429.8750 - val_loss: 308284.5938 - val_mse: 308284.5938
# Epoch 14/20
# 14/14 [==============================] - 0s 4ms/step - loss: 273089.5625 - mse: 273089.5625 - val_loss: 321812.6875 - val_mse: 321812.6875
# Epoch 15/20
# 14/14 [==============================] - 0s 7ms/step - loss: 271373.6875 - mse: 271373.6875 - val_loss: 323127.0312 - val_mse: 323127.0312
# Epoch 16/20
# 14/14 [==============================] - 0s 6ms/step - loss: 270710.8125 - mse: 270710.8125 - val_loss: 312001.8125 - val_mse: 312001.8125
# Epoch 17/20
# 14/14 [==============================] - 0s 5ms/step - loss: 269760.2500 - mse: 269760.2500 - val_loss: 317322.2500 - val_mse: 317322.2500
# Epoch 18/20
# 14/14 [==============================] - 0s 5ms/step - loss: 272517.2500 - mse: 272517.2500 - val_loss: 318998.2188 - val_mse: 318998.2188
# Epoch 19/20
# 14/14 [==============================] - 0s 4ms/step - loss: 272491.8438 - mse: 272491.8438 - val_loss: 317502.0000 - val_mse: 317502.0000
# Epoch 20/20
# 14/14 [==============================] - 0s 4ms/step - loss: 270325.1562 - mse: 270325.1562 - val_loss: 317591.6875 - val_mse: 317591.6875
# 2/2 [==============================] - 0s 5ms/step
# 0.39862579196925674

# %% [markdown]
# GPU_AMD

# %%
GPU_AMD=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/NV.csv")
GPU_AMD.head()
# Out:
#    laptop_ID Company             Product TypeName  Inches  \
# 0        151     MSI         GE72MVR 7RG   Gaming    17.3
# 1       1232    Asus           ROG Strix   Gaming    17.3
# 2       1251     MSI       GE72VR Apache   Gaming    17.3
# 3        306    Asus  Rog GL702VS-GC095T   Gaming    17.3
# 4        584  Lenovo  IdeaPad Y910-17ISK   Gaming    17.3
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 1            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 2            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 4  IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz           6933
#
#     Ram               Memory  Memory_benchmark                   Gpu  \
# 0  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 1  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 2  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 3  16GB  256GB SSD + 1TB HDD             69.98    Nvidia GeForce 920
# 4  32GB  256GB SSD + 1TB HDD             69.98   Nvidia GeForce 920M
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            6.5  Windows 10   2.1kg      1145.00
# 1            6.5  Windows 10  2.77kg       999.00
# 2            6.5  Windows 10  2.77kg      1549.00
# 3            3.6       Linux   2.1kg       519.00
# 4            3.6  Windows 10   2.2kg       720.32

# %%
features_GPU_AMD = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_AMD, X_raw_test_GPU_AMD, Y_GPU_AMD, Y_test_GPU_AMD = train_test_split(GPU_AMD[features_GPU_AMD].values, GPU_AMD[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_AMD)
X_GPU_AMD = scaler.transform(X_raw_GPU_AMD)
X_test_GPU_AMD = scaler.transform(X_raw_test_GPU_AMD)

# formatting
Y_GPU_AMD = Y_GPU_AMD.reshape((-1, 1))
Y_test_GPU_AMD = Y_test_GPU_AMD.reshape((-1, 1))

model_GPU_AMD=Sequential([
    Dense(units=25,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=10,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_AMD.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_AMD = model_GPU_AMD.fit(
    x=X_GPU_AMD,
    y=Y_GPU_AMD,
    batch_size=8,
    epochs=20,
    validation_data=(X_test_GPU_AMD, Y_test_GPU_AMD),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_AMD, 'mse')
yhat_GPU_AMD= model_GPU_AMD.predict(X_test_GPU_AMD)

r2_GPU_AMD = np.power(yhat_GPU_AMD - np.mean(Y_test_GPU_AMD), 2).sum() / np.power(Y_test_GPU_AMD - np.mean(Y_test_GPU_AMD), 2).sum()
r2_GPU_AMD
# Out:
# Epoch 1/20
# 28/28 [==============================] - 1s 14ms/step - loss: 2970697.2500 - mse: 2970697.2500 - val_loss: 3214609.2500 - val_mse: 3214609.2500
# Epoch 2/20
# 28/28 [==============================] - 0s 5ms/step - loss: 2950171.7500 - mse: 2950171.7500 - val_loss: 3146171.2500 - val_mse: 3146171.2500
# Epoch 3/20
# 28/28 [==============================] - 0s 5ms/step - loss: 2721944.5000 - mse: 2721944.5000 - val_loss: 2598364.2500 - val_mse: 2598364.2500
# Epoch 4/20
# 28/28 [==============================] - 0s 5ms/step - loss: 1746657.5000 - mse: 1746657.5000 - val_loss: 998483.5625 - val_mse: 998483.5625
# Epoch 5/20
# 28/28 [==============================] - 0s 5ms/step - loss: 382035.6875 - mse: 382035.6875 - val_loss: 303085.0625 - val_mse: 303085.0625
# Epoch 6/20
# 28/28 [==============================] - 0s 5ms/step - loss: 286937.5625 - mse: 286937.5625 - val_loss: 316333.0625 - val_mse: 316333.0625
# Epoch 7/20
# 28/28 [==============================] - 0s 5ms/step - loss: 272164.9688 - mse: 272164.9688 - val_loss: 331272.0312 - val_mse: 331272.0312
# Epoch 8/20
# 28/28 [==============================] - 0s 5ms/step - loss: 273498.4062 - mse: 273498.4062 - val_loss: 324417.9688 - val_mse: 324417.9688
# Epoch 9/20
# 28/28 [==============================] - 0s 5ms/step - loss: 270963.8125 - mse: 270963.8125 - val_loss: 315980.0312 - val_mse: 315980.0312
# Epoch 10/20
# 28/28 [==============================] - 0s 4ms/step - loss: 275202.0312 - mse: 275202.0312 - val_loss: 327783.3125 - val_mse: 327783.3125
# Epoch 11/20
# 28/28 [==============================] - 0s 3ms/step - loss: 271764.6875 - mse: 271764.6875 - val_loss: 319465.6250 - val_mse: 319465.6250
# Epoch 12/20
# 28/28 [==============================] - 0s 3ms/step - loss: 271666.8438 - mse: 271666.8438 - val_loss: 312573.9688 - val_mse: 312573.9688
# Epoch 13/20
# 28/28 [==============================] - 0s 3ms/step - loss: 274713.5000 - mse: 274713.5000 - val_loss: 340889.9062 - val_mse: 340889.9062
# Epoch 14/20
# 28/28 [==============================] - 0s 3ms/step - loss: 277814.3750 - mse: 277814.3750 - val_loss: 318120.2500 - val_mse: 318120.2500
# Epoch 15/20
# 28/28 [==============================] - 0s 3ms/step - loss: 270903.3125 - mse: 270903.3125 - val_loss: 331170.5938 - val_mse: 331170.5938
# Epoch 16/20
# 28/28 [==============================] - 0s 3ms/step - loss: 270151.7188 - mse: 270151.7188 - val_loss: 310732.3125 - val_mse: 310732.3125
# Epoch 17/20
# 28/28 [==============================] - 0s 3ms/step - loss: 270554.3438 - mse: 270554.3438 - val_loss: 321872.0000 - val_mse: 321872.0000
# Epoch 18/20
# 28/28 [==============================] - 0s 4ms/step - loss: 273122.6562 - mse: 273122.6562 - val_loss: 328267.7812 - val_mse: 328267.7812
# Epoch 19/20
# 28/28 [==============================] - 0s 4ms/step - loss: 272384.0625 - mse: 272384.0625 - val_loss: 322836.2812 - val_mse: 322836.2812
# Epoch 20/20
# 28/28 [==============================] - 0s 3ms/step - loss: 316106.6562 - mse: 316106.6562 - val_loss: 301930.9688 - val_mse: 301930.9688
# 2/2 [==============================] - 0s 7ms/step
# 0.5058705363051721

# %% [markdown]
# GPU_Intel

# %%
GPU_Intel=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/Intel.csv")
GPU_Intel.head()
# Out:
#    laptop_ID Company            Product  TypeName  Inches  \
# 0       1274    Asus  Rog G752VT-GC073T    Gaming    17.3
# 1        286    Dell      Inspiron 3567  Notebook    15.6
# 2        897    Dell        Vostro 3568  Notebook    15.6
# 3        910    Dell        Vostro 3568  Notebook    15.6
# 4        979    Dell      Inspiron 3567  Notebook    15.6
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0  IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz           6528
# 1            Full HD 1920x1080   Intel Core i3 6006U 2.0GHz           2273
# 2                     1366x768   Intel Core i3 6006U 2.0GHz           2273
# 3                     1366x768   Intel Core i3 6006U 2.0GHz           2273
# 4                     1366x768   Intel Core i3 6006U 2.0GHz           2273
#
#     Ram               Memory  Memory_benchmark                    Gpu  \
# 0  16GB  128GB SSD + 1TB HDD             58.98     Intel Graphics 620
# 1   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 2   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 3   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 4   4GB              1TB HDD             39.99  Intel HD Graphics 400
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            3.9  Windows 10   1.8kg        919.0
# 1            1.1   Chrome OS  1.25kg        389.0
# 2            1.1   Chrome OS   1.5kg        325.0
# 3            1.1       No OS  1.86kg        299.0
# 4            1.1     Android  0.69kg        549.0

# %%
features_GPU_Intel = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_Intel, X_raw_test_GPU_Intel, Y_GPU_Intel, Y_test_GPU_Intel = train_test_split(GPU_Intel[features_GPU_Intel].values, GPU_Intel[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_Intel)
X_GPU_Intel = scaler.transform(X_raw_GPU_Intel)
X_test_GPU_Intel = scaler.transform(X_raw_test_GPU_Intel)

# formatting
Y_GPU_Intel = Y_GPU_Intel.reshape((-1, 1))
Y_test_GPU_Intel = Y_test_GPU_Intel.reshape((-1, 1))

model_GPU_Intel=Sequential([
    Dense(units=15,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=8,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=3,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_Intel.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_Intel = model_GPU_Intel.fit(
    x=X_GPU_Intel,
    y=Y_GPU_Intel,
    batch_size=8,
    epochs=20,
    validation_data=(X_test_GPU_Intel, Y_test_GPU_Intel),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_Intel, 'mse')
yhat_GPU_Intel= model_GPU_Intel.predict(X_test_GPU_Intel)

r2_GPU_Intel = np.power(yhat_GPU_Intel - np.mean(Y_test_GPU_Intel), 2).sum() / np.power(Y_test_GPU_Intel - np.mean(Y_test_GPU_Intel), 2).sum()
r2_GPU_Intel
# Out:
# Epoch 1/20
# 62/62 [==============================] - 1s 5ms/step - loss: 1365561.6250 - mse: 1365561.6250 - val_loss: 1527510.0000 - val_mse: 1527510.0000
# Epoch 2/20
# 62/62 [==============================] - 0s 3ms/step - loss: 1089491.3750 - mse: 1089491.3750 - val_loss: 761143.3125 - val_mse: 761143.3125
# Epoch 3/20
# 62/62 [==============================] - 0s 2ms/step - loss: 343594.4688 - mse: 343594.4688 - val_loss: 455347.7500 - val_mse: 455347.7500
# Epoch 4/20
# 62/62 [==============================] - 0s 4ms/step - loss: 289850.5938 - mse: 289850.5938 - val_loss: 399593.5000 - val_mse: 399593.5000
# Epoch 5/20
# 62/62 [==============================] - 0s 4ms/step - loss: 264466.3750 - mse: 264466.3750 - val_loss: 364837.1250 - val_mse: 364837.1250
# Epoch 6/20
# 62/62 [==============================] - 0s 6ms/step - loss: 260799.3125 - mse: 260799.3125 - val_loss: 348702.4375 - val_mse: 348702.4375
# Epoch 7/20
# 62/62 [==============================] - 0s 5ms/step - loss: 255762.0312 - mse: 255762.0312 - val_loss: 345210.7188 - val_mse: 345210.7188
# Epoch 8/20
# 62/62 [==============================] - 0s 6ms/step - loss: 256355.3281 - mse: 256355.3281 - val_loss: 345859.5000 - val_mse: 345859.5000
# Epoch 9/20
# 62/62 [==============================] - 0s 5ms/step - loss: 257185.5625 - mse: 257185.5625 - val_loss: 351279.4688 - val_mse: 351279.4688
# Epoch 10/20
# 62/62 [==============================] - 0s 5ms/step - loss: 255794.3750 - mse: 255794.3750 - val_loss: 344449.5938 - val_mse: 344449.5938
# Epoch 11/20
# 62/62 [==============================] - 0s 5ms/step - loss: 256085.4688 - mse: 256085.4688 - val_loss: 348287.8750 - val_mse: 348287.8750
# Epoch 12/20
# 62/62 [==============================] - 0s 5ms/step - loss: 255652.8594 - mse: 255652.8594 - val_loss: 345420.1562 - val_mse: 345420.1562
# Epoch 13/20
# 62/62 [==============================] - 0s 5ms/step - loss: 257963.9375 - mse: 257963.9375 - val_loss: 344741.0000 - val_mse: 344741.0000
# Epoch 14/20
# 62/62 [==============================] - 0s 6ms/step - loss: 256364.1406 - mse: 256364.1406 - val_loss: 345804.4688 - val_mse: 345804.4688
# Epoch 15/20
# 62/62 [==============================] - 0s 5ms/step - loss: 255411.7188 - mse: 255411.7188 - val_loss: 346381.5312 - val_mse: 346381.5312
# Epoch 16/20
# 62/62 [==============================] - 0s 6ms/step - loss: 256275.5312 - mse: 256275.5312 - val_loss: 345349.8125 - val_mse: 345349.8125
# Epoch 17/20
# 62/62 [==============================] - 0s 6ms/step - loss: 255980.8438 - mse: 255980.8438 - val_loss: 351469.3125 - val_mse: 351469.3125
# Epoch 18/20
# 62/62 [==============================] - 0s 4ms/step - loss: 256288.5000 - mse: 256288.5000 - val_loss: 348347.1562 - val_mse: 348347.1562
# Epoch 19/20
# 62/62 [==============================] - 0s 3ms/step - loss: 255682.8125 - mse: 255682.8125 - val_loss: 343865.8438 - val_mse: 343865.8438
# Epoch 20/20
# 62/62 [==============================] - 0s 3ms/step - loss: 259435.9688 - mse: 259435.9688 - val_loss: 350232.9062 - val_mse: 350232.9062
# 4/4 [==============================] - 0s 3ms/step
# 0.15988450488232164
