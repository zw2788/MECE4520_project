# %% [markdown]
# <a href="https://colab.research.google.com/github/zw2788/MECE4520_project/blob/main/MECE_4520_LaptopPrediction/test_0.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Neural Network

# %%
from typing import Tuple
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set(font_scale=1.5)
sns.set_style("whitegrid", {'grid.linestyle':'--'})

import numpy as np
import pandas as pd

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/Laptop_Intel1012.csv")
data.head()
# Out:
#    laptop_ID Company             Product            TypeName  Inches  \
# 0        739    Dell       Inspiron 3567            Notebook    15.6
# 1        898    Asus  Rog GL753VD-GC082T              Gaming    17.3
# 2         45    Dell       Inspiron 7773  2 in 1 Convertible    17.3
# 3        399    Acer            Aspire 5            Notebook    15.6
# 4        476  Lenovo      Thinkpad T460s           Ultrabook    14.0
#
#                   ScreenResolution                          Cpu  \
# 0                         1366x768   Intel Core i5 7200U 2.5GHz
# 1                Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz
# 2  Full HD / Touchscreen 1920x1080   Intel Core i5 8250U 1.6GHz
# 3               IPS Panel 1366x768   Intel Core i5 8250U 1.6GHz
# 4     IPS Panel Quad HD+ 2560x1440   Intel Core i7 6600U 2.6GHz
#
#    CPU_benchmark   Ram  Ram_benchmark               Memory  Memory_benchmark  \
# 0           3397  12GB             12              1TB HDD             39.99
# 1           5092  12GB             12  128GB SSD + 1TB HDD             58.98
# 2           5901  12GB             12              1TB HDD             39.99
# 3           5901  12GB             12              1TB HDD             39.99
# 4           3474  12GB             12            256GB SSD             22.99
#
#                       Gpu  GPU_benchmark       OpSys  Weight  \
# 0   Intel HD Graphics 520            3.5  Windows 10   2.3kg
# 1      AMD Radeon R5 M430            3.1  Windows 10  1.90kg
# 2   Intel HD Graphics 520            3.5  Windows 10  1.86kg
# 3   Intel HD Graphics 520            3.5  Windows 10   1.2kg
# 4  Intel HD Graphics 6000            3.9       macOS  1.34kg
#
#    Weight_benchmark  Price_euros
# 0              2.30       418.64
# 1              1.90       817.95
# 2              1.86       469.00
# 3              1.20      1535.00
# 4              1.34       898.94

# %%
# We can choose the features needed here
features = [
    "GPU_benchmark",
    "Memory_benchmark",
    "CPU_benchmark",
    "Weight_benchmark",
    "Ram_benchmark"

]
label = "Price_euros"

# train test split
X_raw, X_raw_test, Y, Y_test = train_test_split(data[features].values, data[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw)
X = scaler.transform(X_raw)
X_test = scaler.transform(X_raw_test)

# formatting
Y = Y.reshape((-1, 1))
Y_test = Y_test.reshape((-1, 1))

# %%
fig = plt.figure(figsize=(16,6))
axes = fig.add_subplot(1, 1, 1)
axes.plot(X, Y, 'ro')
axes.set_xlabel('x')
axes.set_ylabel('u_ture')
axes.grid()

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam


model=Sequential([
    Dense(units=50,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=20,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history = model.fit(
    x=X,
    y=Y,
    batch_size=32,
    epochs=20,
    validation_data=(X_test, Y_test),
    verbose=1,
    shuffle=True,
)
# Out:
# Epoch 1/20
# 26/26 [==============================] - 1s 6ms/step - loss: 1723102.5000 - mse: 1723102.5000 - val_loss: 1794176.0000 - val_mse: 1794176.0000
# Epoch 2/20
# 26/26 [==============================] - 0s 2ms/step - loss: 1560836.3750 - mse: 1560836.3750 - val_loss: 1217051.0000 - val_mse: 1217051.0000
# Epoch 3/20
# 26/26 [==============================] - 0s 2ms/step - loss: 627037.1875 - mse: 627037.1875 - val_loss: 436464.0938 - val_mse: 436464.0938
# Epoch 4/20
# 26/26 [==============================] - 0s 2ms/step - loss: 279503.1562 - mse: 279503.1562 - val_loss: 281539.2500 - val_mse: 281539.2500
# Epoch 5/20
# 26/26 [==============================] - 0s 2ms/step - loss: 229895.7500 - mse: 229895.7500 - val_loss: 249113.3594 - val_mse: 249113.3594
# Epoch 6/20
# 26/26 [==============================] - 0s 2ms/step - loss: 214302.6094 - mse: 214302.6094 - val_loss: 230160.0938 - val_mse: 230160.0938
# Epoch 7/20
# 26/26 [==============================] - 0s 2ms/step - loss: 202368.2188 - mse: 202368.2188 - val_loss: 219012.1250 - val_mse: 219012.1250
# Epoch 8/20
# 26/26 [==============================] - 0s 2ms/step - loss: 192972.9219 - mse: 192972.9219 - val_loss: 209263.5469 - val_mse: 209263.5469
# Epoch 9/20
# 26/26 [==============================] - 0s 2ms/step - loss: 192149.1875 - mse: 192149.1875 - val_loss: 201196.8906 - val_mse: 201196.8906
# Epoch 10/20
# 26/26 [==============================] - 0s 3ms/step - loss: 189674.4688 - mse: 189674.4688 - val_loss: 201922.1875 - val_mse: 201922.1875
# Epoch 11/20
# 26/26 [==============================] - 0s 2ms/step - loss: 191791.4844 - mse: 191791.4844 - val_loss: 198445.7969 - val_mse: 198445.7969
# Epoch 12/20
# 26/26 [==============================] - 0s 3ms/step - loss: 184095.5000 - mse: 184095.5000 - val_loss: 191198.8750 - val_mse: 191198.8750
# Epoch 13/20
# 26/26 [==============================] - 0s 2ms/step - loss: 181146.9531 - mse: 181146.9531 - val_loss: 192196.5938 - val_mse: 192196.5938
# Epoch 14/20
# 26/26 [==============================] - 0s 3ms/step - loss: 182591.2344 - mse: 182591.2344 - val_loss: 189799.9844 - val_mse: 189799.9844
# Epoch 15/20
# 26/26 [==============================] - 0s 2ms/step - loss: 182078.1406 - mse: 182078.1406 - val_loss: 195462.9531 - val_mse: 195462.9531
# Epoch 16/20
# 26/26 [==============================] - 0s 2ms/step - loss: 181426.5938 - mse: 181426.5938 - val_loss: 192804.9062 - val_mse: 192804.9062
# Epoch 17/20
# 26/26 [==============================] - 0s 2ms/step - loss: 178855.1406 - mse: 178855.1406 - val_loss: 189519.5625 - val_mse: 189519.5625
# Epoch 18/20
# 26/26 [==============================] - 0s 2ms/step - loss: 179130.7812 - mse: 179130.7812 - val_loss: 189478.1719 - val_mse: 189478.1719
# Epoch 19/20
# 26/26 [==============================] - 0s 2ms/step - loss: 181953.2500 - mse: 181953.2500 - val_loss: 189348.0625 - val_mse: 189348.0625
# Epoch 20/20
# 26/26 [==============================] - 0s 3ms/step - loss: 178528.6406 - mse: 178528.6406 - val_loss: 186539.2188 - val_mse: 186539.2188

# %%
def plot_history(history, key):
  plt.plot(history.history[key])
  plt.plot(history.history['val_'+key])
  plt.xlabel("Epochs")
  plt.ylabel(key)
  plt.legend([key, 'val_'+key])
  plt.show()
# Plot the history
plot_history(history, 'mse')

# %%
yhat= model.predict(X_test)
model.summary()
# Out:
# 7/7 [==============================] - 0s 1ms/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 50)                300
#
#  dense_5 (Dense)             (None, 20)                1020
#
#  dense_6 (Dense)             (None, 5)                 105
#
#  dense_7 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 1,431
# Trainable params: 1,431
# Non-trainable params: 0
# _________________________________________________________________

# %%
r2 = np.power(yhat - np.mean(Y_test), 2).sum() / np.power(Y_test - np.mean(Y_test), 2).sum()
r2
# Out:
# 0.6855634184886265

# %% [markdown]
# GPU_NV

# %%
GPU_NV=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/NV.csv")
GPU_NV.head()
# Out:
#    laptop_ID Company             Product TypeName  Inches  \
# 0        151     MSI         GE72MVR 7RG   Gaming    17.3
# 1       1232    Asus           ROG Strix   Gaming    17.3
# 2       1251     MSI       GE72VR Apache   Gaming    17.3
# 3        306    Asus  Rog GL702VS-GC095T   Gaming    17.3
# 4        584  Lenovo  IdeaPad Y910-17ISK   Gaming    17.3
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 1            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 2            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 4  IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz           6933
#
#     Ram               Memory  Memory_benchmark                   Gpu  \
# 0  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 1  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 2  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 3  16GB  256GB SSD + 1TB HDD             69.98    Nvidia GeForce 920
# 4  32GB  256GB SSD + 1TB HDD             69.98   Nvidia GeForce 920M
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            6.5  Windows 10   2.1kg      1145.00
# 1            6.5  Windows 10  2.77kg       999.00
# 2            6.5  Windows 10  2.77kg      1549.00
# 3            3.6       Linux   2.1kg       519.00
# 4            3.6  Windows 10   2.2kg       720.32

# %%
features_GPU_NV = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_NV, X_raw_test_GPU_NV, Y_GPU_NV, Y_test_GPU_NV = train_test_split(GPU_NV[features_GPU_NV].values, GPU_NV[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_NV)
X_GPU_NV = scaler.transform(X_raw_GPU_NV)
X_test_GPU_NV = scaler.transform(X_raw_test_GPU_NV)

# formatting
Y_GPU_NV = Y_GPU_NV.reshape((-1, 1))
Y_test_GPU_NV = Y_test_GPU_NV.reshape((-1, 1))

model_GPU_NV=Sequential([
    Dense(units=25,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=15,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_NV.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_NV = model_GPU_NV.fit(
    x=X_GPU_NV,
    y=Y_GPU_NV,
    batch_size=16,
    epochs=20,
    validation_data=(X_test_GPU_NV, Y_test_GPU_NV),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_NV, 'mse')
yhat_GPU_NV= model_GPU_NV.predict(X_test_GPU_NV)

r2_GPU_NV = np.power(yhat_GPU_NV - np.mean(Y_test_GPU_NV), 2).sum() / np.power(Y_test_GPU_NV - np.mean(Y_test_GPU_NV), 2).sum()
r2_GPU_NV
# Out:
# Epoch 1/20
# 14/14 [==============================] - 1s 12ms/step - loss: 2971302.7500 - mse: 2971302.7500 - val_loss: 3217235.0000 - val_mse: 3217235.0000
# Epoch 2/20
# 14/14 [==============================] - 0s 3ms/step - loss: 2968966.5000 - mse: 2968966.5000 - val_loss: 3211780.0000 - val_mse: 3211780.0000
# Epoch 3/20
# 14/14 [==============================] - 0s 3ms/step - loss: 2955729.5000 - mse: 2955729.5000 - val_loss: 3181714.5000 - val_mse: 3181714.5000
# Epoch 4/20
# 14/14 [==============================] - 0s 3ms/step - loss: 2897607.7500 - mse: 2897607.7500 - val_loss: 3067983.5000 - val_mse: 3067983.5000
# Epoch 5/20
# 14/14 [==============================] - 0s 4ms/step - loss: 2697728.5000 - mse: 2697728.5000 - val_loss: 2754492.2500 - val_mse: 2754492.2500
# Epoch 6/20
# 14/14 [==============================] - 0s 3ms/step - loss: 2250029.0000 - mse: 2250029.0000 - val_loss: 2086910.5000 - val_mse: 2086910.5000
# Epoch 7/20
# 14/14 [==============================] - 0s 3ms/step - loss: 1433566.1250 - mse: 1433566.1250 - val_loss: 1124444.7500 - val_mse: 1124444.7500
# Epoch 8/20
# 14/14 [==============================] - 0s 4ms/step - loss: 569070.7500 - mse: 569070.7500 - val_loss: 450953.5938 - val_mse: 450953.5938
# Epoch 9/20
# 14/14 [==============================] - 0s 4ms/step - loss: 315777.2500 - mse: 315777.2500 - val_loss: 336614.9688 - val_mse: 336614.9688
# Epoch 10/20
# 14/14 [==============================] - 0s 4ms/step - loss: 279862.2188 - mse: 279862.2188 - val_loss: 316487.8125 - val_mse: 316487.8125
# Epoch 11/20
# 14/14 [==============================] - 0s 3ms/step - loss: 272409.8125 - mse: 272409.8125 - val_loss: 325615.0938 - val_mse: 325615.0938
# Epoch 12/20
# 14/14 [==============================] - 0s 3ms/step - loss: 271150.3750 - mse: 271150.3750 - val_loss: 313887.3750 - val_mse: 313887.3750
# Epoch 13/20
# 14/14 [==============================] - 0s 3ms/step - loss: 269990.8125 - mse: 269990.8125 - val_loss: 312974.9688 - val_mse: 312974.9688
# Epoch 14/20
# 14/14 [==============================] - 0s 4ms/step - loss: 270634.4375 - mse: 270634.4375 - val_loss: 320500.1875 - val_mse: 320500.1875
# Epoch 15/20
# 14/14 [==============================] - 0s 3ms/step - loss: 269674.7812 - mse: 269674.7812 - val_loss: 322842.2500 - val_mse: 322842.2500
# Epoch 16/20
# 14/14 [==============================] - 0s 3ms/step - loss: 269144.6875 - mse: 269144.6875 - val_loss: 323593.0938 - val_mse: 323593.0938
# Epoch 17/20
# 14/14 [==============================] - 0s 3ms/step - loss: 269094.7500 - mse: 269094.7500 - val_loss: 317462.6562 - val_mse: 317462.6562
# Epoch 18/20
# 14/14 [==============================] - 0s 4ms/step - loss: 272199.9688 - mse: 272199.9688 - val_loss: 313794.5000 - val_mse: 313794.5000
# Epoch 19/20
# 14/14 [==============================] - 0s 3ms/step - loss: 268888.2500 - mse: 268888.2500 - val_loss: 319395.2812 - val_mse: 319395.2812
# Epoch 20/20
# 14/14 [==============================] - 0s 3ms/step - loss: 268167.9375 - mse: 268167.9375 - val_loss: 319021.7500 - val_mse: 319021.7500
# 2/2 [==============================] - 0s 3ms/step
# 0.3988135797468234

# %% [markdown]
# GPU_AMD

# %%
GPU_AMD=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/NV.csv")
GPU_AMD.head()
# Out:
#    laptop_ID Company             Product TypeName  Inches  \
# 0        151     MSI         GE72MVR 7RG   Gaming    17.3
# 1       1232    Asus           ROG Strix   Gaming    17.3
# 2       1251     MSI       GE72VR Apache   Gaming    17.3
# 3        306    Asus  Rog GL702VS-GC095T   Gaming    17.3
# 4        584  Lenovo  IdeaPad Y910-17ISK   Gaming    17.3
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 1            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 2            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 4  IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz           6933
#
#     Ram               Memory  Memory_benchmark                   Gpu  \
# 0  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 1  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 2  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 3  16GB  256GB SSD + 1TB HDD             69.98    Nvidia GeForce 920
# 4  32GB  256GB SSD + 1TB HDD             69.98   Nvidia GeForce 920M
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            6.5  Windows 10   2.1kg      1145.00
# 1            6.5  Windows 10  2.77kg       999.00
# 2            6.5  Windows 10  2.77kg      1549.00
# 3            3.6       Linux   2.1kg       519.00
# 4            3.6  Windows 10   2.2kg       720.32

# %%
features_GPU_AMD = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_AMD, X_raw_test_GPU_AMD, Y_GPU_AMD, Y_test_GPU_AMD = train_test_split(GPU_AMD[features_GPU_AMD].values, GPU_AMD[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_AMD)
X_GPU_AMD = scaler.transform(X_raw_GPU_AMD)
X_test_GPU_AMD = scaler.transform(X_raw_test_GPU_AMD)

# formatting
Y_GPU_AMD = Y_GPU_AMD.reshape((-1, 1))
Y_test_GPU_AMD = Y_test_GPU_AMD.reshape((-1, 1))

model_GPU_AMD=Sequential([
    Dense(units=25,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=10,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_AMD.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_AMD = model_GPU_AMD.fit(
    x=X_GPU_AMD,
    y=Y_GPU_AMD,
    batch_size=8,
    epochs=20,
    validation_data=(X_test_GPU_AMD, Y_test_GPU_AMD),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_AMD, 'mse')
yhat_GPU_AMD= model_GPU_AMD.predict(X_test_GPU_AMD)

r2_GPU_AMD = np.power(yhat_GPU_AMD - np.mean(Y_test_GPU_AMD), 2).sum() / np.power(Y_test_GPU_AMD - np.mean(Y_test_GPU_AMD), 2).sum()
r2_GPU_AMD
# Out:
# Epoch 1/20
# 28/28 [==============================] - 1s 6ms/step - loss: 2970295.5000 - mse: 2970295.5000 - val_loss: 3211173.7500 - val_mse: 3211173.7500
# Epoch 2/20
# 28/28 [==============================] - 0s 2ms/step - loss: 2918161.5000 - mse: 2918161.5000 - val_loss: 3040797.7500 - val_mse: 3040797.7500
# Epoch 3/20
# 28/28 [==============================] - 0s 3ms/step - loss: 2409277.2500 - mse: 2409277.2500 - val_loss: 1924439.0000 - val_mse: 1924439.0000
# Epoch 4/20
# 28/28 [==============================] - 0s 3ms/step - loss: 863568.0625 - mse: 863568.0625 - val_loss: 437368.5938 - val_mse: 437368.5938
# Epoch 5/20
# 28/28 [==============================] - 0s 2ms/step - loss: 319359.8750 - mse: 319359.8750 - val_loss: 340584.8438 - val_mse: 340584.8438
# Epoch 6/20
# 28/28 [==============================] - 0s 2ms/step - loss: 284228.7500 - mse: 284228.7500 - val_loss: 319496.2500 - val_mse: 319496.2500
# Epoch 7/20
# 28/28 [==============================] - 0s 2ms/step - loss: 271320.2500 - mse: 271320.2500 - val_loss: 326044.1562 - val_mse: 326044.1562
# Epoch 8/20
# 28/28 [==============================] - 0s 2ms/step - loss: 271392.5312 - mse: 271392.5312 - val_loss: 312015.9062 - val_mse: 312015.9062
# Epoch 9/20
# 28/28 [==============================] - 0s 2ms/step - loss: 273728.1562 - mse: 273728.1562 - val_loss: 315490.2188 - val_mse: 315490.2188
# Epoch 10/20
# 28/28 [==============================] - 0s 2ms/step - loss: 272261.0625 - mse: 272261.0625 - val_loss: 320084.7500 - val_mse: 320084.7500
# Epoch 11/20
# 28/28 [==============================] - 0s 2ms/step - loss: 274628.1875 - mse: 274628.1875 - val_loss: 312743.1250 - val_mse: 312743.1250
# Epoch 12/20
# 28/28 [==============================] - 0s 2ms/step - loss: 274775.6250 - mse: 274775.6250 - val_loss: 325125.4688 - val_mse: 325125.4688
# Epoch 13/20
# 28/28 [==============================] - 0s 2ms/step - loss: 274113.1875 - mse: 274113.1875 - val_loss: 311479.9375 - val_mse: 311479.9375
# Epoch 14/20
# 28/28 [==============================] - 0s 2ms/step - loss: 274159.9375 - mse: 274159.9375 - val_loss: 316452.5938 - val_mse: 316452.5938
# Epoch 15/20
# 28/28 [==============================] - 0s 2ms/step - loss: 272038.9062 - mse: 272038.9062 - val_loss: 311600.3750 - val_mse: 311600.3750
# Epoch 16/20
# 28/28 [==============================] - 0s 2ms/step - loss: 271948.7500 - mse: 271948.7500 - val_loss: 330931.3750 - val_mse: 330931.3750
# Epoch 17/20
# 28/28 [==============================] - 0s 2ms/step - loss: 273466.8750 - mse: 273466.8750 - val_loss: 314717.0625 - val_mse: 314717.0625
# Epoch 18/20
# 28/28 [==============================] - 0s 3ms/step - loss: 276893.5625 - mse: 276893.5625 - val_loss: 327947.2812 - val_mse: 327947.2812
# Epoch 19/20
# 28/28 [==============================] - 0s 2ms/step - loss: 279030.0000 - mse: 279030.0000 - val_loss: 314275.1562 - val_mse: 314275.1562
# Epoch 20/20
# 28/28 [==============================] - 0s 2ms/step - loss: 275960.5625 - mse: 275960.5625 - val_loss: 308483.7188 - val_mse: 308483.7188
# 2/2 [==============================] - 0s 5ms/step
# 0.43744653598200794

# %% [markdown]
# GPU_Intel

# %%
GPU_Intel=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/Intel.csv")
GPU_Intel.head()
# Out:
#    laptop_ID Company            Product  TypeName  Inches  \
# 0       1274    Asus  Rog G752VT-GC073T    Gaming    17.3
# 1        286    Dell      Inspiron 3567  Notebook    15.6
# 2        897    Dell        Vostro 3568  Notebook    15.6
# 3        910    Dell        Vostro 3568  Notebook    15.6
# 4        979    Dell      Inspiron 3567  Notebook    15.6
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0  IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz           6528
# 1            Full HD 1920x1080   Intel Core i3 6006U 2.0GHz           2273
# 2                     1366x768   Intel Core i3 6006U 2.0GHz           2273
# 3                     1366x768   Intel Core i3 6006U 2.0GHz           2273
# 4                     1366x768   Intel Core i3 6006U 2.0GHz           2273
#
#     Ram               Memory  Memory_benchmark                    Gpu  \
# 0  16GB  128GB SSD + 1TB HDD             58.98     Intel Graphics 620
# 1   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 2   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 3   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 4   4GB              1TB HDD             39.99  Intel HD Graphics 400
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            3.9  Windows 10   1.8kg        919.0
# 1            1.1   Chrome OS  1.25kg        389.0
# 2            1.1   Chrome OS   1.5kg        325.0
# 3            1.1       No OS  1.86kg        299.0
# 4            1.1     Android  0.69kg        549.0

# %%
features_GPU_Intel = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_Intel, X_raw_test_GPU_Intel, Y_GPU_Intel, Y_test_GPU_Intel = train_test_split(GPU_Intel[features_GPU_Intel].values, GPU_Intel[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_Intel)
X_GPU_Intel = scaler.transform(X_raw_GPU_Intel)
X_test_GPU_Intel = scaler.transform(X_raw_test_GPU_Intel)

# formatting
Y_GPU_Intel = Y_GPU_Intel.reshape((-1, 1))
Y_test_GPU_Intel = Y_test_GPU_Intel.reshape((-1, 1))

model_GPU_Intel=Sequential([
    Dense(units=15,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=8,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=3,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_Intel.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_Intel = model_GPU_Intel.fit(
    x=X_GPU_Intel,
    y=Y_GPU_Intel,
    batch_size=8,
    epochs=20,
    validation_data=(X_test_GPU_Intel, Y_test_GPU_Intel),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_Intel, 'mse')
yhat_GPU_Intel= model_GPU_Intel.predict(X_test_GPU_Intel)

r2_GPU_Intel = np.power(yhat_GPU_Intel - np.mean(Y_test_GPU_Intel), 2).sum() / np.power(Y_test_GPU_Intel - np.mean(Y_test_GPU_Intel), 2).sum()
r2_GPU_Intel
# Out:
# Epoch 1/20
# 62/62 [==============================] - 1s 3ms/step - loss: 1362959.7500 - mse: 1362959.7500 - val_loss: 1510054.1250 - val_mse: 1510054.1250
# Epoch 2/20
# 62/62 [==============================] - 0s 2ms/step - loss: 957002.2500 - mse: 957002.2500 - val_loss: 562125.7500 - val_mse: 562125.7500
# Epoch 3/20
# 62/62 [==============================] - 0s 2ms/step - loss: 304964.1250 - mse: 304964.1250 - val_loss: 421119.0000 - val_mse: 421119.0000
# Epoch 4/20
# 62/62 [==============================] - 0s 2ms/step - loss: 279470.0625 - mse: 279470.0625 - val_loss: 369363.8438 - val_mse: 369363.8438
# Epoch 5/20
# 62/62 [==============================] - 0s 2ms/step - loss: 258880.3750 - mse: 258880.3750 - val_loss: 363074.7500 - val_mse: 363074.7500
# Epoch 6/20
# 62/62 [==============================] - 0s 2ms/step - loss: 258450.6719 - mse: 258450.6719 - val_loss: 354504.8750 - val_mse: 354504.8750
# Epoch 7/20
# 62/62 [==============================] - 0s 2ms/step - loss: 257792.5781 - mse: 257792.5781 - val_loss: 344938.7500 - val_mse: 344938.7500
# Epoch 8/20
# 62/62 [==============================] - 0s 2ms/step - loss: 255832.0000 - mse: 255832.0000 - val_loss: 348587.1250 - val_mse: 348587.1250
# Epoch 9/20
# 62/62 [==============================] - 0s 2ms/step - loss: 256669.8438 - mse: 256669.8438 - val_loss: 345377.7500 - val_mse: 345377.7500
# Epoch 10/20
# 62/62 [==============================] - 0s 2ms/step - loss: 259259.0156 - mse: 259259.0156 - val_loss: 349477.1250 - val_mse: 349477.1250
# Epoch 11/20
# 62/62 [==============================] - 0s 2ms/step - loss: 258566.4688 - mse: 258566.4688 - val_loss: 345288.3750 - val_mse: 345288.3750
# Epoch 12/20
# 62/62 [==============================] - 0s 2ms/step - loss: 255744.5156 - mse: 255744.5156 - val_loss: 347775.3438 - val_mse: 347775.3438
# Epoch 13/20
# 62/62 [==============================] - 0s 2ms/step - loss: 256670.4688 - mse: 256670.4688 - val_loss: 348438.0625 - val_mse: 348438.0625
# Epoch 14/20
# 62/62 [==============================] - 0s 2ms/step - loss: 256529.5625 - mse: 256529.5625 - val_loss: 347638.2500 - val_mse: 347638.2500
# Epoch 15/20
# 62/62 [==============================] - 0s 2ms/step - loss: 255225.4375 - mse: 255225.4375 - val_loss: 345522.9688 - val_mse: 345522.9688
# Epoch 16/20
# 62/62 [==============================] - 0s 2ms/step - loss: 256355.7969 - mse: 256355.7969 - val_loss: 345278.7188 - val_mse: 345278.7188
# Epoch 17/20
# 62/62 [==============================] - 0s 2ms/step - loss: 255748.8594 - mse: 255748.8594 - val_loss: 348437.7188 - val_mse: 348437.7188
# Epoch 18/20
# 62/62 [==============================] - 0s 2ms/step - loss: 257200.5000 - mse: 257200.5000 - val_loss: 344316.9375 - val_mse: 344316.9375
# Epoch 19/20
# 62/62 [==============================] - 0s 2ms/step - loss: 256733.8125 - mse: 256733.8125 - val_loss: 345152.7188 - val_mse: 345152.7188
# Epoch 20/20
# 62/62 [==============================] - 0s 1ms/step - loss: 257481.1094 - mse: 257481.1094 - val_loss: 350921.2500 - val_mse: 350921.2500
# 4/4 [==============================] - 0s 2ms/step
# 0.151931973105728
