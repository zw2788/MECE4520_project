# %% [markdown]
# <a href="https://colab.research.google.com/github/zw2788/MECE4520_project/blob/main/MECE_4520_LaptopPrediction/test_0.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Neural Network

# %%
from typing import Tuple
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set(font_scale=1.5)
sns.set_style("whitegrid", {'grid.linestyle':'--'})

import numpy as np
import pandas as pd

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/Laptop_Intel1012.csv")
data.head()
# Out:
#    laptop_ID Company             Product            TypeName  Inches  \
# 0        739    Dell       Inspiron 3567            Notebook    15.6
# 1        898    Asus  Rog GL753VD-GC082T              Gaming    17.3
# 2         45    Dell       Inspiron 7773  2 in 1 Convertible    17.3
# 3        399    Acer            Aspire 5            Notebook    15.6
# 4        476  Lenovo      Thinkpad T460s           Ultrabook    14.0
#
#                   ScreenResolution                          Cpu  \
# 0                         1366x768   Intel Core i5 7200U 2.5GHz
# 1                Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz
# 2  Full HD / Touchscreen 1920x1080   Intel Core i5 8250U 1.6GHz
# 3               IPS Panel 1366x768   Intel Core i5 8250U 1.6GHz
# 4     IPS Panel Quad HD+ 2560x1440   Intel Core i7 6600U 2.6GHz
#
#    CPU_benchmark   Ram  Ram_benchmark               Memory  Memory_benchmark  \
# 0           3397  12GB             12              1TB HDD             39.99
# 1           5092  12GB             12  128GB SSD + 1TB HDD             58.98
# 2           5901  12GB             12              1TB HDD             39.99
# 3           5901  12GB             12              1TB HDD             39.99
# 4           3474  12GB             12            256GB SSD             22.99
#
#                       Gpu  GPU_benchmark       OpSys  Weight  \
# 0   Intel HD Graphics 520            3.5  Windows 10   2.3kg
# 1      AMD Radeon R5 M430            3.1  Windows 10  1.90kg
# 2   Intel HD Graphics 520            3.5  Windows 10  1.86kg
# 3   Intel HD Graphics 520            3.5  Windows 10   1.2kg
# 4  Intel HD Graphics 6000            3.9       macOS  1.34kg
#
#    Weight_benchmark  Price_euros
# 0              2.30       418.64
# 1              1.90       817.95
# 2              1.86       469.00
# 3              1.20      1535.00
# 4              1.34       898.94

# %%
# We can choose the features needed here
features = [
    "GPU_benchmark",
    "Memory_benchmark",
    "CPU_benchmark",
    "Weight_benchmark",
    "Ram_benchmark"

]
label = "Price_euros"

# train test split
X_raw, X_raw_test, Y, Y_test = train_test_split(data[features].values, data[label].values, test_size=0.1, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw)
X = scaler.transform(X_raw)
X_test = scaler.transform(X_raw_test)

# formatting
Y = Y.reshape((-1, 1))
Y_test = Y_test.reshape((-1, 1))

# %%
fig = plt.figure(figsize=(16,6))
axes = fig.add_subplot(1, 1, 1)
axes.plot(X, Y, 'ro')
axes.set_xlabel('x')
axes.set_ylabel('u_ture')
axes.grid()

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam


model=Sequential([
    Dense(units=50,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=20,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history = model.fit(
    x=X,
    y=Y,
    batch_size=32,
    epochs=20,
    validation_data=(X_test, Y_test),
    verbose=1,
    shuffle=True,
)
# Out:
# Epoch 1/20
# 29/29 [==============================] - 3s 29ms/step - loss: 1711766.1250 - mse: 1711766.1250 - val_loss: 1980302.7500 - val_mse: 1980302.7500
# Epoch 2/20
# 29/29 [==============================] - 0s 15ms/step - loss: 1494592.7500 - mse: 1494592.7500 - val_loss: 1181553.5000 - val_mse: 1181553.5000
# Epoch 3/20
# 29/29 [==============================] - 1s 18ms/step - loss: 484912.3125 - mse: 484912.3125 - val_loss: 428521.5938 - val_mse: 428521.5938
# Epoch 4/20
# 29/29 [==============================] - 0s 12ms/step - loss: 276857.5938 - mse: 276857.5938 - val_loss: 299702.5000 - val_mse: 299702.5000
# Epoch 5/20
# 29/29 [==============================] - 0s 11ms/step - loss: 227099.8125 - mse: 227099.8125 - val_loss: 258689.7969 - val_mse: 258689.7969
# Epoch 6/20
# 29/29 [==============================] - 0s 12ms/step - loss: 207254.6406 - mse: 207254.6406 - val_loss: 242122.1562 - val_mse: 242122.1562
# Epoch 7/20
# 29/29 [==============================] - 1s 20ms/step - loss: 195315.9688 - mse: 195315.9688 - val_loss: 219047.0469 - val_mse: 219047.0469
# Epoch 8/20
# 29/29 [==============================] - 1s 22ms/step - loss: 190176.5625 - mse: 190176.5625 - val_loss: 227664.8750 - val_mse: 227664.8750
# Epoch 9/20
# 29/29 [==============================] - 1s 18ms/step - loss: 189046.7500 - mse: 189046.7500 - val_loss: 223436.5938 - val_mse: 223436.5938
# Epoch 10/20
# 29/29 [==============================] - 0s 17ms/step - loss: 184805.2188 - mse: 184805.2188 - val_loss: 207928.5625 - val_mse: 207928.5625
# Epoch 11/20
# 29/29 [==============================] - 1s 18ms/step - loss: 184299.0625 - mse: 184299.0625 - val_loss: 211013.5625 - val_mse: 211013.5625
# Epoch 12/20
# 29/29 [==============================] - 1s 24ms/step - loss: 184384.0000 - mse: 184384.0000 - val_loss: 204193.0625 - val_mse: 204193.0625
# Epoch 13/20
# 29/29 [==============================] - 0s 17ms/step - loss: 182685.6562 - mse: 182685.6562 - val_loss: 208279.2344 - val_mse: 208279.2344
# Epoch 14/20
# 29/29 [==============================] - 1s 30ms/step - loss: 181703.8594 - mse: 181703.8594 - val_loss: 218042.5469 - val_mse: 218042.5469
# Epoch 15/20
# 29/29 [==============================] - 1s 18ms/step - loss: 180035.0312 - mse: 180035.0312 - val_loss: 203548.3906 - val_mse: 203548.3906
# Epoch 16/20
# 29/29 [==============================] - 1s 20ms/step - loss: 179032.7344 - mse: 179032.7344 - val_loss: 204640.3594 - val_mse: 204640.3594
# Epoch 17/20
# 29/29 [==============================] - 0s 13ms/step - loss: 179371.4219 - mse: 179371.4219 - val_loss: 205216.3281 - val_mse: 205216.3281
# Epoch 18/20
# 29/29 [==============================] - 1s 22ms/step - loss: 180015.6250 - mse: 180015.6250 - val_loss: 202908.2969 - val_mse: 202908.2969
# Epoch 19/20
# 29/29 [==============================] - 0s 13ms/step - loss: 178853.5938 - mse: 178853.5938 - val_loss: 206152.7500 - val_mse: 206152.7500
# Epoch 20/20
# 29/29 [==============================] - 1s 23ms/step - loss: 178254.7031 - mse: 178254.7031 - val_loss: 199878.3594 - val_mse: 199878.3594

# %%
def plot_history(history, key):
  plt.plot(history.history[key])
  plt.plot(history.history['val_'+key])
  plt.xlabel("Epochs")
  plt.ylabel(key)
  plt.legend([key, 'val_'+key])
  plt.show()
# Plot the history
plot_history(history, 'mse')

# %%
yhat= model.predict(X_test)
model.summary()
# Out:
# 4/4 [==============================] - 0s 3ms/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                300
#
#  dense_1 (Dense)             (None, 20)                1020
#
#  dense_2 (Dense)             (None, 5)                 105
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 1,431
# Trainable params: 1,431
# Non-trainable params: 0
# _________________________________________________________________

# %%
r2 = np.power(yhat - np.mean(Y_test), 2).sum() / np.power(Y_test - np.mean(Y_test), 2).sum()
r2
# Out:
# 0.7009933021101289

# %% [markdown]
# GPU_NV

# %%
GPU_NV=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/NV.csv")
GPU_NV.head()
# Out:
#    laptop_ID Company             Product TypeName  Inches  \
# 0        151     MSI         GE72MVR 7RG   Gaming    17.3
# 1       1232    Asus           ROG Strix   Gaming    17.3
# 2       1251     MSI       GE72VR Apache   Gaming    17.3
# 3        306    Asus  Rog GL702VS-GC095T   Gaming    17.3
# 4        584  Lenovo  IdeaPad Y910-17ISK   Gaming    17.3
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 1            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 2            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 4  IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz           6933
#
#     Ram               Memory  Memory_benchmark                   Gpu  \
# 0  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 1  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 2  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 3  16GB  256GB SSD + 1TB HDD             69.98    Nvidia GeForce 920
# 4  32GB  256GB SSD + 1TB HDD             69.98   Nvidia GeForce 920M
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            6.5  Windows 10   2.1kg      1145.00
# 1            6.5  Windows 10  2.77kg       999.00
# 2            6.5  Windows 10  2.77kg      1549.00
# 3            3.6       Linux   2.1kg       519.00
# 4            3.6  Windows 10   2.2kg       720.32

# %%
features_GPU_NV = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_NV, X_raw_test_GPU_NV, Y_GPU_NV, Y_test_GPU_NV = train_test_split(GPU_NV[features_GPU_NV].values, GPU_NV[label].values, test_size=0.1, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_NV)
X_GPU_NV = scaler.transform(X_raw_GPU_NV)
X_test_GPU_NV = scaler.transform(X_raw_test_GPU_NV)

# formatting
Y_GPU_NV = Y_GPU_NV.reshape((-1, 1))
Y_test_GPU_NV = Y_test_GPU_NV.reshape((-1, 1))

model_GPU_NV=Sequential([
    Dense(units=25,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=15,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_NV.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_NV = model_GPU_NV.fit(
    x=X_GPU_NV,
    y=Y_GPU_NV,
    batch_size=16,
    epochs=20,
    validation_data=(X_test_GPU_NV, Y_test_GPU_NV),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_NV, 'mse')
yhat_GPU_NV= model_GPU_NV.predict(X_test_GPU_NV)

r2_GPU_NV = np.power(yhat_GPU_NV - np.mean(Y_test_GPU_NV), 2).sum() / np.power(Y_test_GPU_NV - np.mean(Y_test_GPU_NV), 2).sum()
r2_GPU_NV
# Out:
# Epoch 1/20
# 16/16 [==============================] - 1s 12ms/step - loss: 2905569.2500 - mse: 2905569.2500 - val_loss: 4022923.2500 - val_mse: 4022923.2500
# Epoch 2/20
# 16/16 [==============================] - 0s 4ms/step - loss: 2895552.7500 - mse: 2895552.7500 - val_loss: 3986466.7500 - val_mse: 3986466.7500
# Epoch 3/20
# 16/16 [==============================] - 0s 4ms/step - loss: 2810826.7500 - mse: 2810826.7500 - val_loss: 3764385.7500 - val_mse: 3764385.7500
# Epoch 4/20
# 16/16 [==============================] - 0s 4ms/step - loss: 2458104.2500 - mse: 2458104.2500 - val_loss: 2980263.7500 - val_mse: 2980263.7500
# Epoch 5/20
# 16/16 [==============================] - 0s 3ms/step - loss: 1511290.5000 - mse: 1511290.5000 - val_loss: 1415148.2500 - val_mse: 1415148.2500
# Epoch 6/20
# 16/16 [==============================] - 0s 4ms/step - loss: 496231.5938 - mse: 496231.5938 - val_loss: 499084.5312 - val_mse: 499084.5312
# Epoch 7/20
# 16/16 [==============================] - 0s 3ms/step - loss: 295366.1875 - mse: 295366.1875 - val_loss: 443671.2500 - val_mse: 443671.2500
# Epoch 8/20
# 16/16 [==============================] - 0s 3ms/step - loss: 262138.5625 - mse: 262138.5625 - val_loss: 468336.7812 - val_mse: 468336.7812
# Epoch 9/20
# 16/16 [==============================] - 0s 4ms/step - loss: 262468.8125 - mse: 262468.8125 - val_loss: 446593.0000 - val_mse: 446593.0000
# Epoch 10/20
# 16/16 [==============================] - 0s 4ms/step - loss: 260429.0938 - mse: 260429.0938 - val_loss: 449466.2188 - val_mse: 449466.2188
# Epoch 11/20
# 16/16 [==============================] - 0s 4ms/step - loss: 261164.6875 - mse: 261164.6875 - val_loss: 467407.7188 - val_mse: 467407.7188
# Epoch 12/20
# 16/16 [==============================] - 0s 4ms/step - loss: 258854.9062 - mse: 258854.9062 - val_loss: 460701.2812 - val_mse: 460701.2812
# Epoch 13/20
# 16/16 [==============================] - 0s 4ms/step - loss: 256905.8438 - mse: 256905.8438 - val_loss: 462456.4688 - val_mse: 462456.4688
# Epoch 14/20
# 16/16 [==============================] - 0s 4ms/step - loss: 257230.9375 - mse: 257230.9375 - val_loss: 453628.6562 - val_mse: 453628.6562
# Epoch 15/20
# 16/16 [==============================] - 0s 4ms/step - loss: 261757.2344 - mse: 261757.2344 - val_loss: 464737.0000 - val_mse: 464737.0000
# Epoch 16/20
# 16/16 [==============================] - 0s 4ms/step - loss: 260368.6719 - mse: 260368.6719 - val_loss: 470133.0625 - val_mse: 470133.0625
# Epoch 17/20
# 16/16 [==============================] - 0s 4ms/step - loss: 255957.7969 - mse: 255957.7969 - val_loss: 447485.5000 - val_mse: 447485.5000
# Epoch 18/20
# 16/16 [==============================] - 0s 4ms/step - loss: 257676.6406 - mse: 257676.6406 - val_loss: 462817.0312 - val_mse: 462817.0312
# Epoch 19/20
# 16/16 [==============================] - 0s 3ms/step - loss: 259796.6406 - mse: 259796.6406 - val_loss: 461478.1562 - val_mse: 461478.1562
# Epoch 20/20
# 16/16 [==============================] - 0s 3ms/step - loss: 258857.7656 - mse: 258857.7656 - val_loss: 460134.3125 - val_mse: 460134.3125
# 1/1 [==============================] - 0s 64ms/step
# 0.46740434943049886

# %% [markdown]
# GPU_AMD

# %%
GPU_AMD=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/NV.csv")
GPU_AMD.head()
# Out:
#    laptop_ID Company             Product TypeName  Inches  \
# 0        151     MSI         GE72MVR 7RG   Gaming    17.3
# 1       1232    Asus           ROG Strix   Gaming    17.3
# 2       1251     MSI       GE72VR Apache   Gaming    17.3
# 3        306    Asus  Rog GL702VS-GC095T   Gaming    17.3
# 4        584  Lenovo  IdeaPad Y910-17ISK   Gaming    17.3
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 1            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 2            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 4  IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz           6933
#
#     Ram               Memory  Memory_benchmark                   Gpu  \
# 0  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 1  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 2  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 3  16GB  256GB SSD + 1TB HDD             69.98    Nvidia GeForce 920
# 4  32GB  256GB SSD + 1TB HDD             69.98   Nvidia GeForce 920M
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            6.5  Windows 10   2.1kg      1145.00
# 1            6.5  Windows 10  2.77kg       999.00
# 2            6.5  Windows 10  2.77kg      1549.00
# 3            3.6       Linux   2.1kg       519.00
# 4            3.6  Windows 10   2.2kg       720.32

# %%
features_GPU_AMD = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_AMD, X_raw_test_GPU_AMD, Y_GPU_AMD, Y_test_GPU_AMD = train_test_split(GPU_AMD[features_GPU_AMD].values, GPU_AMD[label].values, test_size=0.1, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_AMD)
X_GPU_AMD = scaler.transform(X_raw_GPU_AMD)
X_test_GPU_AMD = scaler.transform(X_raw_test_GPU_AMD)

# formatting
Y_GPU_AMD = Y_GPU_AMD.reshape((-1, 1))
Y_test_GPU_AMD = Y_test_GPU_AMD.reshape((-1, 1))

model_GPU_AMD=Sequential([
    Dense(units=25,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=10,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_AMD.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_AMD = model_GPU_AMD.fit(
    x=X_GPU_AMD,
    y=Y_GPU_AMD,
    batch_size=8,
    epochs=20,
    validation_data=(X_test_GPU_AMD, Y_test_GPU_AMD),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_AMD, 'mse')
yhat_GPU_AMD= model_GPU_AMD.predict(X_test_GPU_AMD)

r2_GPU_AMD = np.power(yhat_GPU_AMD - np.mean(Y_test_GPU_AMD), 2).sum() / np.power(Y_test_GPU_AMD - np.mean(Y_test_GPU_AMD), 2).sum()
r2_GPU_AMD
# Out:
# Epoch 1/20
# 31/31 [==============================] - 1s 7ms/step - loss: 2902978.0000 - mse: 2902978.0000 - val_loss: 4006536.5000 - val_mse: 4006536.5000
# Epoch 2/20
# 31/31 [==============================] - 0s 3ms/step - loss: 2791623.7500 - mse: 2791623.7500 - val_loss: 3582438.0000 - val_mse: 3582438.0000
# Epoch 3/20
# 31/31 [==============================] - 0s 3ms/step - loss: 1888505.2500 - mse: 1888505.2500 - val_loss: 1434410.0000 - val_mse: 1434410.0000
# Epoch 4/20
# 31/31 [==============================] - 0s 4ms/step - loss: 385939.7188 - mse: 385939.7188 - val_loss: 418328.0625 - val_mse: 418328.0625
# Epoch 5/20
# 31/31 [==============================] - 0s 3ms/step - loss: 268341.4062 - mse: 268341.4062 - val_loss: 487511.5625 - val_mse: 487511.5625
# Epoch 6/20
# 31/31 [==============================] - 0s 3ms/step - loss: 258102.0312 - mse: 258102.0312 - val_loss: 454207.4375 - val_mse: 454207.4375
# Epoch 7/20
# 31/31 [==============================] - 0s 3ms/step - loss: 259300.0781 - mse: 259300.0781 - val_loss: 464375.5938 - val_mse: 464375.5938
# Epoch 8/20
# 31/31 [==============================] - 0s 3ms/step - loss: 261908.1094 - mse: 261908.1094 - val_loss: 471631.2812 - val_mse: 471631.2812
# Epoch 9/20
# 31/31 [==============================] - 0s 3ms/step - loss: 260813.7969 - mse: 260813.7969 - val_loss: 491069.1875 - val_mse: 491069.1875
# Epoch 10/20
# 31/31 [==============================] - 0s 3ms/step - loss: 264287.8750 - mse: 264287.8750 - val_loss: 435815.3125 - val_mse: 435815.3125
# Epoch 11/20
# 31/31 [==============================] - 0s 3ms/step - loss: 263808.5000 - mse: 263808.5000 - val_loss: 495583.6875 - val_mse: 495583.6875
# Epoch 12/20
# 31/31 [==============================] - 0s 3ms/step - loss: 260542.5781 - mse: 260542.5781 - val_loss: 445465.7812 - val_mse: 445465.7812
# Epoch 13/20
# 31/31 [==============================] - 0s 3ms/step - loss: 257180.9688 - mse: 257180.9688 - val_loss: 474544.7812 - val_mse: 474544.7812
# Epoch 14/20
# 31/31 [==============================] - 0s 3ms/step - loss: 264141.9375 - mse: 264141.9375 - val_loss: 469785.7188 - val_mse: 469785.7188
# Epoch 15/20
# 31/31 [==============================] - 0s 3ms/step - loss: 262011.2500 - mse: 262011.2500 - val_loss: 470739.7188 - val_mse: 470739.7188
# Epoch 16/20
# 31/31 [==============================] - 0s 3ms/step - loss: 262909.3750 - mse: 262909.3750 - val_loss: 500614.5625 - val_mse: 500614.5625
# Epoch 17/20
# 31/31 [==============================] - 0s 3ms/step - loss: 260884.9375 - mse: 260884.9375 - val_loss: 442074.2812 - val_mse: 442074.2812
# Epoch 18/20
# 31/31 [==============================] - 0s 4ms/step - loss: 264581.3750 - mse: 264581.3750 - val_loss: 461589.1562 - val_mse: 461589.1562
# Epoch 19/20
# 31/31 [==============================] - 0s 3ms/step - loss: 265797.9375 - mse: 265797.9375 - val_loss: 463117.5625 - val_mse: 463117.5625
# Epoch 20/20
# 31/31 [==============================] - 0s 4ms/step - loss: 262626.5625 - mse: 262626.5625 - val_loss: 470238.4688 - val_mse: 470238.4688
# 1/1 [==============================] - 0s 57ms/step
# 0.44865459196423063

# %% [markdown]
# GPU_Intel

# %%
GPU_Intel=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/Intel.csv")
GPU_Intel.head()
# Out:
#    laptop_ID Company            Product  TypeName  Inches  \
# 0       1274    Asus  Rog G752VT-GC073T    Gaming    17.3
# 1        286    Dell      Inspiron 3567  Notebook    15.6
# 2        897    Dell        Vostro 3568  Notebook    15.6
# 3        910    Dell        Vostro 3568  Notebook    15.6
# 4        979    Dell      Inspiron 3567  Notebook    15.6
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0  IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz           6528
# 1            Full HD 1920x1080   Intel Core i3 6006U 2.0GHz           2273
# 2                     1366x768   Intel Core i3 6006U 2.0GHz           2273
# 3                     1366x768   Intel Core i3 6006U 2.0GHz           2273
# 4                     1366x768   Intel Core i3 6006U 2.0GHz           2273
#
#     Ram               Memory  Memory_benchmark                    Gpu  \
# 0  16GB  128GB SSD + 1TB HDD             58.98     Intel Graphics 620
# 1   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 2   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 3   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 4   4GB              1TB HDD             39.99  Intel HD Graphics 400
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            3.9  Windows 10   1.8kg        919.0
# 1            1.1   Chrome OS  1.25kg        389.0
# 2            1.1   Chrome OS   1.5kg        325.0
# 3            1.1       No OS  1.86kg        299.0
# 4            1.1     Android  0.69kg        549.0

# %%
features_GPU_Intel = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_Intel, X_raw_test_GPU_Intel, Y_GPU_Intel, Y_test_GPU_Intel = train_test_split(GPU_Intel[features_GPU_Intel].values, GPU_Intel[label].values, test_size=0.1, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_Intel)
X_GPU_Intel = scaler.transform(X_raw_GPU_Intel)
X_test_GPU_Intel = scaler.transform(X_raw_test_GPU_Intel)

# formatting
Y_GPU_Intel = Y_GPU_Intel.reshape((-1, 1))
Y_test_GPU_Intel = Y_test_GPU_Intel.reshape((-1, 1))

model_GPU_Intel=Sequential([
    Dense(units=15,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=8,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=3,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_Intel.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_Intel = model_GPU_Intel.fit(
    x=X_GPU_Intel,
    y=Y_GPU_Intel,
    batch_size=8,
    epochs=20,
    validation_data=(X_test_GPU_Intel, Y_test_GPU_Intel),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_Intel, 'mse')
yhat_GPU_Intel= model_GPU_Intel.predict(X_test_GPU_Intel)

r2_GPU_Intel = np.power(yhat_GPU_Intel - np.mean(Y_test_GPU_Intel), 2).sum() / np.power(Y_test_GPU_Intel - np.mean(Y_test_GPU_Intel), 2).sum()
r2_GPU_Intel
# Out:
# Epoch 1/20
# 69/69 [==============================] - 1s 4ms/step - loss: 1357052.0000 - mse: 1357052.0000 - val_loss: 1353535.6250 - val_mse: 1353535.6250
# Epoch 2/20
# 69/69 [==============================] - 0s 3ms/step - loss: 567593.6250 - mse: 567593.6250 - val_loss: 359309.5625 - val_mse: 359309.5625
# Epoch 3/20
# 69/69 [==============================] - 0s 2ms/step - loss: 279269.0000 - mse: 279269.0000 - val_loss: 332077.1250 - val_mse: 332077.1250
# Epoch 4/20
# 69/69 [==============================] - 0s 2ms/step - loss: 272326.3125 - mse: 272326.3125 - val_loss: 313043.5938 - val_mse: 313043.5938
# Epoch 5/20
# 69/69 [==============================] - 0s 2ms/step - loss: 273283.0000 - mse: 273283.0000 - val_loss: 327650.1250 - val_mse: 327650.1250
# Epoch 6/20
# 69/69 [==============================] - 0s 2ms/step - loss: 275382.3750 - mse: 275382.3750 - val_loss: 310721.2812 - val_mse: 310721.2812
# Epoch 7/20
# 69/69 [==============================] - 0s 3ms/step - loss: 270428.5312 - mse: 270428.5312 - val_loss: 317643.7500 - val_mse: 317643.7500
# Epoch 8/20
# 69/69 [==============================] - 0s 2ms/step - loss: 269395.1875 - mse: 269395.1875 - val_loss: 312220.9375 - val_mse: 312220.9375
# Epoch 9/20
# 69/69 [==============================] - 0s 2ms/step - loss: 275182.4062 - mse: 275182.4062 - val_loss: 315918.2500 - val_mse: 315918.2500
# Epoch 10/20
# 69/69 [==============================] - 0s 2ms/step - loss: 273285.3750 - mse: 273285.3750 - val_loss: 328346.4375 - val_mse: 328346.4375
# Epoch 11/20
# 69/69 [==============================] - 0s 2ms/step - loss: 270162.0625 - mse: 270162.0625 - val_loss: 310827.4062 - val_mse: 310827.4062
# Epoch 12/20
# 69/69 [==============================] - 0s 2ms/step - loss: 271111.4688 - mse: 271111.4688 - val_loss: 309488.3125 - val_mse: 309488.3125
# Epoch 13/20
# 69/69 [==============================] - 0s 2ms/step - loss: 269646.3125 - mse: 269646.3125 - val_loss: 311619.4688 - val_mse: 311619.4688
# Epoch 14/20
# 69/69 [==============================] - 0s 3ms/step - loss: 269670.2500 - mse: 269670.2500 - val_loss: 316346.9688 - val_mse: 316346.9688
# Epoch 15/20
# 69/69 [==============================] - 0s 2ms/step - loss: 267763.7812 - mse: 267763.7812 - val_loss: 310606.8438 - val_mse: 310606.8438
# Epoch 16/20
# 69/69 [==============================] - 0s 2ms/step - loss: 273291.5938 - mse: 273291.5938 - val_loss: 330225.2812 - val_mse: 330225.2812
# Epoch 17/20
# 69/69 [==============================] - 0s 3ms/step - loss: 271820.5000 - mse: 271820.5000 - val_loss: 313052.5938 - val_mse: 313052.5938
# Epoch 18/20
# 69/69 [==============================] - 0s 2ms/step - loss: 271552.3125 - mse: 271552.3125 - val_loss: 313400.7500 - val_mse: 313400.7500
# Epoch 19/20
# 69/69 [==============================] - 0s 2ms/step - loss: 270389.5000 - mse: 270389.5000 - val_loss: 314161.9375 - val_mse: 314161.9375
# Epoch 20/20
# 69/69 [==============================] - 0s 2ms/step - loss: 270661.9062 - mse: 270661.9062 - val_loss: 310461.2500 - val_mse: 310461.2500
# 2/2 [==============================] - 0s 5ms/step
# 0.16398733026484275
