# %% [markdown]
# <a href="https://colab.research.google.com/github/zw2788/MECE4520_project/blob/main/MECE_4520_LaptopPrediction/test_0.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Neural Network

# %%
from typing import Tuple
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set(font_scale=1.5)
sns.set_style("whitegrid", {'grid.linestyle':'--'})

import numpy as np
import pandas as pd

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/Laptop_Intel1012.csv")
data.head()
# Out:
#    laptop_ID Company             Product            TypeName  Inches  \
# 0        739    Dell       Inspiron 3567            Notebook    15.6
# 1        898    Asus  Rog GL753VD-GC082T              Gaming    17.3
# 2         45    Dell       Inspiron 7773  2 in 1 Convertible    17.3
# 3        399    Acer            Aspire 5            Notebook    15.6
# 4        476  Lenovo      Thinkpad T460s           Ultrabook    14.0
#
#                   ScreenResolution                          Cpu  \
# 0                         1366x768   Intel Core i5 7200U 2.5GHz
# 1                Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz
# 2  Full HD / Touchscreen 1920x1080   Intel Core i5 8250U 1.6GHz
# 3               IPS Panel 1366x768   Intel Core i5 8250U 1.6GHz
# 4     IPS Panel Quad HD+ 2560x1440   Intel Core i7 6600U 2.6GHz
#
#    CPU_benchmark   Ram  Ram_benchmark               Memory  Memory_benchmark  \
# 0           3397  12GB             12              1TB HDD             39.99
# 1           5092  12GB             12  128GB SSD + 1TB HDD             58.98
# 2           5901  12GB             12              1TB HDD             39.99
# 3           5901  12GB             12              1TB HDD             39.99
# 4           3474  12GB             12            256GB SSD             22.99
#
#                       Gpu  GPU_benchmark       OpSys  Weight  \
# 0   Intel HD Graphics 520            3.5  Windows 10   2.3kg
# 1      AMD Radeon R5 M430            3.1  Windows 10  1.90kg
# 2   Intel HD Graphics 520            3.5  Windows 10  1.86kg
# 3   Intel HD Graphics 520            3.5  Windows 10   1.2kg
# 4  Intel HD Graphics 6000            3.9       macOS  1.34kg
#
#    Weight_benchmark  Price_euros
# 0              2.30       418.64
# 1              1.90       817.95
# 2              1.86       469.00
# 3              1.20      1535.00
# 4              1.34       898.94

# %%
# We can choose the features needed here
features = [
    "GPU_benchmark",
    "Memory_benchmark",
    "CPU_benchmark",
    "Weight_benchmark",
    "Ram_benchmark"

]
label = "Price_euros"

# train test split
X_raw, X_raw_test, Y, Y_test = train_test_split(data[features].values, data[label].values, test_size=0.1, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw)
X = scaler.transform(X_raw)
X_test = scaler.transform(X_raw_test)

# formatting
Y = Y.reshape((-1, 1))
Y_test = Y_test.reshape((-1, 1))

# %%
fig = plt.figure(figsize=(16,6))
axes = fig.add_subplot(1, 1, 1)
axes.plot(X, Y, 'ro')
axes.set_xlabel('x')
axes.set_ylabel('u_ture')
axes.grid()

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam


model=Sequential([
    Dense(units=50,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=20,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history = model.fit(
    x=X,
    y=Y,
    batch_size=32,
    epochs=20,
    validation_data=(X_test, Y_test),
    verbose=1,
    shuffle=True,
)
# Out:
# Epoch 1/20
# 29/29 [==============================] - 1s 8ms/step - loss: 1713858.6250 - mse: 1713858.6250 - val_loss: 1996929.1250 - val_mse: 1996929.1250
# Epoch 2/20
# 29/29 [==============================] - 0s 3ms/step - loss: 1604200.8750 - mse: 1604200.8750 - val_loss: 1571867.8750 - val_mse: 1571867.8750
# Epoch 3/20
# 29/29 [==============================] - 0s 3ms/step - loss: 798018.8750 - mse: 798018.8750 - val_loss: 527851.0000 - val_mse: 527851.0000
# Epoch 4/20
# 29/29 [==============================] - 0s 4ms/step - loss: 298822.1250 - mse: 298822.1250 - val_loss: 321367.2500 - val_mse: 321367.2500
# Epoch 5/20
# 29/29 [==============================] - 0s 5ms/step - loss: 240411.5469 - mse: 240411.5469 - val_loss: 285744.9062 - val_mse: 285744.9062
# Epoch 6/20
# 29/29 [==============================] - 0s 4ms/step - loss: 214006.3281 - mse: 214006.3281 - val_loss: 262176.0938 - val_mse: 262176.0938
# Epoch 7/20
# 29/29 [==============================] - 0s 4ms/step - loss: 206235.5469 - mse: 206235.5469 - val_loss: 250996.3906 - val_mse: 250996.3906
# Epoch 8/20
# 29/29 [==============================] - 0s 3ms/step - loss: 194325.8125 - mse: 194325.8125 - val_loss: 239751.3750 - val_mse: 239751.3750
# Epoch 9/20
# 29/29 [==============================] - 0s 4ms/step - loss: 188793.1562 - mse: 188793.1562 - val_loss: 228553.8750 - val_mse: 228553.8750
# Epoch 10/20
# 29/29 [==============================] - 0s 4ms/step - loss: 187135.4062 - mse: 187135.4062 - val_loss: 227087.2031 - val_mse: 227087.2031
# Epoch 11/20
# 29/29 [==============================] - 0s 3ms/step - loss: 186495.1875 - mse: 186495.1875 - val_loss: 227205.6094 - val_mse: 227205.6094
# Epoch 12/20
# 29/29 [==============================] - 0s 3ms/step - loss: 183617.5156 - mse: 183617.5156 - val_loss: 216103.1719 - val_mse: 216103.1719
# Epoch 13/20
# 29/29 [==============================] - 0s 4ms/step - loss: 181028.0938 - mse: 181028.1094 - val_loss: 211766.9375 - val_mse: 211766.9375
# Epoch 14/20
# 29/29 [==============================] - 0s 4ms/step - loss: 182086.6094 - mse: 182086.6094 - val_loss: 211421.3281 - val_mse: 211421.3281
# Epoch 15/20
# 29/29 [==============================] - 0s 4ms/step - loss: 179377.4844 - mse: 179377.4844 - val_loss: 206142.4844 - val_mse: 206142.4844
# Epoch 16/20
# 29/29 [==============================] - 0s 4ms/step - loss: 183583.1094 - mse: 183583.1094 - val_loss: 206649.1406 - val_mse: 206649.1250
# Epoch 17/20
# 29/29 [==============================] - 0s 3ms/step - loss: 180300.5156 - mse: 180300.5156 - val_loss: 204773.6875 - val_mse: 204773.6875
# Epoch 18/20
# 29/29 [==============================] - 0s 4ms/step - loss: 177998.7812 - mse: 177998.7812 - val_loss: 207114.8594 - val_mse: 207114.8594
# Epoch 19/20
# 29/29 [==============================] - 0s 3ms/step - loss: 179187.9844 - mse: 179187.9844 - val_loss: 207053.2031 - val_mse: 207053.2031
# Epoch 20/20
# 29/29 [==============================] - 0s 3ms/step - loss: 178281.2500 - mse: 178281.2500 - val_loss: 210262.7656 - val_mse: 210262.7656

# %%
def plot_history(history, key):
  plt.plot(history.history[key])
  plt.plot(history.history['val_'+key])
  plt.xlabel("Epochs")
  plt.ylabel(key)
  plt.legend([key, 'val_'+key])
  plt.show()
# Plot the history
plot_history(history, 'mse')

# %%
yhat= model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
r2 = np.power(yhat - np.mean(Y_test), 2).sum() / np.power(Y_test - np.mean(Y_test), 2).sum()
r2
# Out:
# 0.7044957181878991

# %% [markdown]
# GPU_NV

# %%
GPU_NV=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/NV.csv")
GPU_NV.head()
# Out:
#    laptop_ID Company             Product TypeName  Inches  \
# 0        151     MSI         GE72MVR 7RG   Gaming    17.3
# 1       1232    Asus           ROG Strix   Gaming    17.3
# 2       1251     MSI       GE72VR Apache   Gaming    17.3
# 3        306    Asus  Rog GL702VS-GC095T   Gaming    17.3
# 4        584  Lenovo  IdeaPad Y910-17ISK   Gaming    17.3
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 1            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 2            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 4  IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz           6933
#
#     Ram               Memory  Memory_benchmark                   Gpu  \
# 0  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 1  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 2  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 3  16GB  256GB SSD + 1TB HDD             69.98    Nvidia GeForce 920
# 4  32GB  256GB SSD + 1TB HDD             69.98   Nvidia GeForce 920M
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            6.5  Windows 10   2.1kg      1145.00
# 1            6.5  Windows 10  2.77kg       999.00
# 2            6.5  Windows 10  2.77kg      1549.00
# 3            3.6       Linux   2.1kg       519.00
# 4            3.6  Windows 10   2.2kg       720.32

# %%
features_GPU_NV = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_NV, X_raw_test_GPU_NV, Y_GPU_NV, Y_test_GPU_NV = train_test_split(GPU_NV[features_GPU_NV].values, GPU_NV[label].values, test_size=0.1, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_NV)
X_GPU_NV = scaler.transform(X_raw_GPU_NV)
X_test_GPU_NV = scaler.transform(X_raw_test_GPU_NV)

# formatting
Y_GPU_NV = Y_GPU_NV.reshape((-1, 1))
Y_test_GPU_NV = Y_test_GPU_NV.reshape((-1, 1))

model_GPU_NV=Sequential([
    Dense(units=25,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=15,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_NV.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_NV = model_GPU_NV.fit(
    x=X_GPU_NV,
    y=Y_GPU_NV,
    batch_size=16,
    epochs=20,
    validation_data=(X_test_GPU_NV, Y_test_GPU_NV),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_NV, 'mse')
yhat_GPU_NV= model_GPU_NV.predict(X_test_GPU_NV)

r2_GPU_NV = np.power(yhat_GPU_NV - np.mean(Y_test_GPU_NV), 2).sum() / np.power(Y_test_GPU_NV - np.mean(Y_test_GPU_NV), 2).sum()
r2_GPU_NV
# Out:
# Epoch 1/20
# 16/16 [==============================] - 1s 14ms/step - loss: 2905667.7500 - mse: 2905667.7500 - val_loss: 4023738.5000 - val_mse: 4023738.5000
# Epoch 2/20
# 16/16 [==============================] - 0s 4ms/step - loss: 2898589.5000 - mse: 2898589.5000 - val_loss: 3999442.2500 - val_mse: 3999442.2500
# Epoch 3/20
# 16/16 [==============================] - 0s 4ms/step - loss: 2844791.2500 - mse: 2844791.2500 - val_loss: 3851696.7500 - val_mse: 3851696.7500
# Epoch 4/20
# 16/16 [==============================] - 0s 3ms/step - loss: 2592598.0000 - mse: 2592598.0000 - val_loss: 3302974.7500 - val_mse: 3302974.7500
# Epoch 5/20
# 16/16 [==============================] - 0s 4ms/step - loss: 1862247.5000 - mse: 1862247.5000 - val_loss: 1992746.8750 - val_mse: 1992746.8750
# Epoch 6/20
# 16/16 [==============================] - 0s 5ms/step - loss: 723419.5000 - mse: 723419.5000 - val_loss: 638118.1875 - val_mse: 638118.1875
# Epoch 7/20
# 16/16 [==============================] - 0s 4ms/step - loss: 327729.4688 - mse: 327729.4688 - val_loss: 417379.7188 - val_mse: 417379.7188
# Epoch 8/20
# 16/16 [==============================] - 0s 3ms/step - loss: 263172.0000 - mse: 263172.0000 - val_loss: 482521.8125 - val_mse: 482521.8125
# Epoch 9/20
# 16/16 [==============================] - 0s 4ms/step - loss: 268147.9062 - mse: 268147.9062 - val_loss: 445901.5625 - val_mse: 445901.5625
# Epoch 10/20
# 16/16 [==============================] - 0s 4ms/step - loss: 258086.0938 - mse: 258086.0938 - val_loss: 457650.0625 - val_mse: 457650.0625
# Epoch 11/20
# 16/16 [==============================] - 0s 4ms/step - loss: 258667.9062 - mse: 258667.9062 - val_loss: 460510.0625 - val_mse: 460510.0625
# Epoch 12/20
# 16/16 [==============================] - 0s 4ms/step - loss: 257644.3594 - mse: 257644.3594 - val_loss: 464477.5938 - val_mse: 464477.5938
# Epoch 13/20
# 16/16 [==============================] - 0s 4ms/step - loss: 257976.1562 - mse: 257976.1562 - val_loss: 438743.7812 - val_mse: 438743.7812
# Epoch 14/20
# 16/16 [==============================] - 0s 6ms/step - loss: 257705.6875 - mse: 257705.6875 - val_loss: 461452.2188 - val_mse: 461452.2188
# Epoch 15/20
# 16/16 [==============================] - 0s 4ms/step - loss: 259307.6875 - mse: 259307.6875 - val_loss: 457905.6562 - val_mse: 457905.6562
# Epoch 16/20
# 16/16 [==============================] - 0s 4ms/step - loss: 261303.9219 - mse: 261303.9219 - val_loss: 481073.3125 - val_mse: 481073.3125
# Epoch 17/20
# 16/16 [==============================] - 0s 4ms/step - loss: 259762.7812 - mse: 259762.7812 - val_loss: 448215.5000 - val_mse: 448215.5000
# Epoch 18/20
# 16/16 [==============================] - 0s 4ms/step - loss: 256925.0469 - mse: 256925.0469 - val_loss: 470211.4375 - val_mse: 470211.4375
# Epoch 19/20
# 16/16 [==============================] - 0s 3ms/step - loss: 257672.7500 - mse: 257672.7500 - val_loss: 454148.5625 - val_mse: 454148.5625
# Epoch 20/20
# 16/16 [==============================] - 0s 6ms/step - loss: 258515.3750 - mse: 258515.3750 - val_loss: 479981.4375 - val_mse: 479981.4375
# 1/1 [==============================] - 0s 61ms/step
# 0.45829100607292445

# %% [markdown]
# GPU_AMD

# %%
GPU_AMD=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/NV.csv")
GPU_AMD.head()
# Out:
#    laptop_ID Company             Product TypeName  Inches  \
# 0        151     MSI         GE72MVR 7RG   Gaming    17.3
# 1       1232    Asus           ROG Strix   Gaming    17.3
# 2       1251     MSI       GE72VR Apache   Gaming    17.3
# 3        306    Asus  Rog GL702VS-GC095T   Gaming    17.3
# 4        584  Lenovo  IdeaPad Y910-17ISK   Gaming    17.3
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 1            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 2            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 4  IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz           6933
#
#     Ram               Memory  Memory_benchmark                   Gpu  \
# 0  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 1  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 2  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 3  16GB  256GB SSD + 1TB HDD             69.98    Nvidia GeForce 920
# 4  32GB  256GB SSD + 1TB HDD             69.98   Nvidia GeForce 920M
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            6.5  Windows 10   2.1kg      1145.00
# 1            6.5  Windows 10  2.77kg       999.00
# 2            6.5  Windows 10  2.77kg      1549.00
# 3            3.6       Linux   2.1kg       519.00
# 4            3.6  Windows 10   2.2kg       720.32

# %%
features_GPU_AMD = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_AMD, X_raw_test_GPU_AMD, Y_GPU_AMD, Y_test_GPU_AMD = train_test_split(GPU_AMD[features_GPU_AMD].values, GPU_AMD[label].values, test_size=0.1, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_AMD)
X_GPU_AMD = scaler.transform(X_raw_GPU_AMD)
X_test_GPU_AMD = scaler.transform(X_raw_test_GPU_AMD)

# formatting
Y_GPU_AMD = Y_GPU_AMD.reshape((-1, 1))
Y_test_GPU_AMD = Y_test_GPU_AMD.reshape((-1, 1))

model_GPU_AMD=Sequential([
    Dense(units=25,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=10,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_AMD.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_AMD = model_GPU_AMD.fit(
    x=X_GPU_AMD,
    y=Y_GPU_AMD,
    batch_size=8,
    epochs=20,
    validation_data=(X_test_GPU_AMD, Y_test_GPU_AMD),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_AMD, 'mse')
yhat_GPU_AMD= model_GPU_AMD.predict(X_test_GPU_AMD)

r2_GPU_AMD = np.power(yhat_GPU_AMD - np.mean(Y_test_GPU_AMD), 2).sum() / np.power(Y_test_GPU_AMD - np.mean(Y_test_GPU_AMD), 2).sum()
r2_GPU_AMD
# Out:
# Epoch 1/20
# 31/31 [==============================] - 1s 7ms/step - loss: 2902571.2500 - mse: 2902571.2500 - val_loss: 4003378.5000 - val_mse: 4003378.5000
# Epoch 2/20
# 31/31 [==============================] - 0s 3ms/step - loss: 2746125.5000 - mse: 2746125.5000 - val_loss: 3395360.0000 - val_mse: 3395360.0000
# Epoch 3/20
# 31/31 [==============================] - 0s 4ms/step - loss: 1462112.8750 - mse: 1462112.8750 - val_loss: 740239.8750 - val_mse: 740239.8750
# Epoch 4/20
# 31/31 [==============================] - 0s 3ms/step - loss: 288180.6875 - mse: 288180.6875 - val_loss: 461752.6562 - val_mse: 461752.6562
# Epoch 5/20
# 31/31 [==============================] - 0s 3ms/step - loss: 265377.0938 - mse: 265377.0938 - val_loss: 429086.3438 - val_mse: 429086.3438
# Epoch 6/20
# 31/31 [==============================] - 0s 3ms/step - loss: 260562.6250 - mse: 260562.6250 - val_loss: 472687.0000 - val_mse: 472687.0000
# Epoch 7/20
# 31/31 [==============================] - 0s 3ms/step - loss: 264019.7812 - mse: 264019.7812 - val_loss: 493028.7188 - val_mse: 493028.7188
# Epoch 8/20
# 31/31 [==============================] - 0s 3ms/step - loss: 268320.4062 - mse: 268320.4062 - val_loss: 458409.7188 - val_mse: 458409.7188
# Epoch 9/20
# 31/31 [==============================] - 0s 3ms/step - loss: 264941.0938 - mse: 264941.0938 - val_loss: 467604.1562 - val_mse: 467604.1562
# Epoch 10/20
# 31/31 [==============================] - 0s 3ms/step - loss: 262209.9688 - mse: 262209.9688 - val_loss: 466157.1562 - val_mse: 466157.1562
# Epoch 11/20
# 31/31 [==============================] - 0s 3ms/step - loss: 263094.6875 - mse: 263094.6875 - val_loss: 448871.7812 - val_mse: 448871.7812
# Epoch 12/20
# 31/31 [==============================] - 0s 3ms/step - loss: 258665.9688 - mse: 258665.9688 - val_loss: 520933.2812 - val_mse: 520933.2812
# Epoch 13/20
# 31/31 [==============================] - 0s 3ms/step - loss: 262586.8750 - mse: 262586.8750 - val_loss: 429846.7812 - val_mse: 429846.7812
# Epoch 14/20
# 31/31 [==============================] - 0s 3ms/step - loss: 261777.5781 - mse: 261777.5781 - val_loss: 486934.9062 - val_mse: 486934.9062
# Epoch 15/20
# 31/31 [==============================] - 0s 4ms/step - loss: 259031.6250 - mse: 259031.6250 - val_loss: 439255.1562 - val_mse: 439255.1562
# Epoch 16/20
# 31/31 [==============================] - 0s 3ms/step - loss: 261391.2188 - mse: 261391.2188 - val_loss: 482895.2500 - val_mse: 482895.2500
# Epoch 17/20
# 31/31 [==============================] - 0s 3ms/step - loss: 259320.9688 - mse: 259320.9688 - val_loss: 437506.5625 - val_mse: 437506.5625
# Epoch 18/20
# 31/31 [==============================] - 0s 3ms/step - loss: 269531.7500 - mse: 269531.7500 - val_loss: 479084.6562 - val_mse: 479084.6562
# Epoch 19/20
# 31/31 [==============================] - 0s 3ms/step - loss: 257586.6875 - mse: 257586.6875 - val_loss: 457475.3438 - val_mse: 457475.3438
# Epoch 20/20
# 31/31 [==============================] - 0s 4ms/step - loss: 262827.6562 - mse: 262827.6562 - val_loss: 440540.6562 - val_mse: 440540.6562
# 1/1 [==============================] - 0s 57ms/step
# 0.503484952746977

# %% [markdown]
# GPU_Intel

# %%
GPU_Intel=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/Intel.csv")
GPU_Intel.head()
# Out:
#    laptop_ID Company            Product  TypeName  Inches  \
# 0       1274    Asus  Rog G752VT-GC073T    Gaming    17.3
# 1        286    Dell      Inspiron 3567  Notebook    15.6
# 2        897    Dell        Vostro 3568  Notebook    15.6
# 3        910    Dell        Vostro 3568  Notebook    15.6
# 4        979    Dell      Inspiron 3567  Notebook    15.6
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0  IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz           6528
# 1            Full HD 1920x1080   Intel Core i3 6006U 2.0GHz           2273
# 2                     1366x768   Intel Core i3 6006U 2.0GHz           2273
# 3                     1366x768   Intel Core i3 6006U 2.0GHz           2273
# 4                     1366x768   Intel Core i3 6006U 2.0GHz           2273
#
#     Ram               Memory  Memory_benchmark                    Gpu  \
# 0  16GB  128GB SSD + 1TB HDD             58.98     Intel Graphics 620
# 1   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 2   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 3   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 4   4GB              1TB HDD             39.99  Intel HD Graphics 400
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            3.9  Windows 10   1.8kg        919.0
# 1            1.1   Chrome OS  1.25kg        389.0
# 2            1.1   Chrome OS   1.5kg        325.0
# 3            1.1       No OS  1.86kg        299.0
# 4            1.1     Android  0.69kg        549.0

# %%
features_GPU_Intel = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_Intel, X_raw_test_GPU_Intel, Y_GPU_Intel, Y_test_GPU_Intel = train_test_split(GPU_Intel[features_GPU_Intel].values, GPU_Intel[label].values, test_size=0.1, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_Intel)
X_GPU_Intel = scaler.transform(X_raw_GPU_Intel)
X_test_GPU_Intel = scaler.transform(X_raw_test_GPU_Intel)

# formatting
Y_GPU_Intel = Y_GPU_Intel.reshape((-1, 1))
Y_test_GPU_Intel = Y_test_GPU_Intel.reshape((-1, 1))

model_GPU_Intel=Sequential([
    Dense(units=15,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=8,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=3,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_Intel.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_Intel = model_GPU_Intel.fit(
    x=X_GPU_Intel,
    y=Y_GPU_Intel,
    batch_size=8,
    epochs=20,
    validation_data=(X_test_GPU_Intel, Y_test_GPU_Intel),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_Intel, 'mse')
yhat_GPU_Intel= model_GPU_Intel.predict(X_test_GPU_Intel)

r2_GPU_Intel = np.power(yhat_GPU_Intel - np.mean(Y_test_GPU_Intel), 2).sum() / np.power(Y_test_GPU_Intel - np.mean(Y_test_GPU_Intel), 2).sum()
r2_GPU_Intel
# Out:
# Epoch 1/20
# 69/69 [==============================] - 1s 4ms/step - loss: 1348854.5000 - mse: 1348854.5000 - val_loss: 1309658.8750 - val_mse: 1309658.8750
# Epoch 2/20
# 69/69 [==============================] - 0s 3ms/step - loss: 527091.3125 - mse: 527091.3125 - val_loss: 377031.5312 - val_mse: 377031.5312
# Epoch 3/20
# 69/69 [==============================] - 0s 3ms/step - loss: 277353.1562 - mse: 277353.1562 - val_loss: 332136.6875 - val_mse: 332136.6875
# Epoch 4/20
# 69/69 [==============================] - 0s 2ms/step - loss: 274150.0000 - mse: 274150.0000 - val_loss: 318542.5938 - val_mse: 318542.5938
# Epoch 5/20
# 69/69 [==============================] - 0s 2ms/step - loss: 273252.7500 - mse: 273252.7500 - val_loss: 314552.1562 - val_mse: 314552.1562
# Epoch 6/20
# 69/69 [==============================] - 0s 2ms/step - loss: 271969.7500 - mse: 271969.7500 - val_loss: 318721.3750 - val_mse: 318721.3750
# Epoch 7/20
# 69/69 [==============================] - 0s 2ms/step - loss: 270764.6250 - mse: 270764.6250 - val_loss: 312076.2188 - val_mse: 312076.2188
# Epoch 8/20
# 69/69 [==============================] - 0s 2ms/step - loss: 272850.6250 - mse: 272850.6250 - val_loss: 317596.5625 - val_mse: 317596.5625
# Epoch 9/20
# 69/69 [==============================] - 0s 2ms/step - loss: 271588.0938 - mse: 271588.0938 - val_loss: 324882.8125 - val_mse: 324882.8125
# Epoch 10/20
# 69/69 [==============================] - 0s 2ms/step - loss: 270515.6875 - mse: 270515.6875 - val_loss: 308914.2812 - val_mse: 308914.2812
# Epoch 11/20
# 69/69 [==============================] - 0s 2ms/step - loss: 270399.9688 - mse: 270399.9688 - val_loss: 310768.4375 - val_mse: 310768.4375
# Epoch 12/20
# 69/69 [==============================] - 0s 3ms/step - loss: 269606.1562 - mse: 269606.1562 - val_loss: 312899.3125 - val_mse: 312899.3125
# Epoch 13/20
# 69/69 [==============================] - 0s 2ms/step - loss: 272138.1562 - mse: 272138.1562 - val_loss: 312180.7188 - val_mse: 312180.7188
# Epoch 14/20
# 69/69 [==============================] - 0s 3ms/step - loss: 269476.5625 - mse: 269476.5625 - val_loss: 320121.6562 - val_mse: 320121.6562
# Epoch 15/20
# 69/69 [==============================] - 0s 3ms/step - loss: 270549.9375 - mse: 270549.9375 - val_loss: 317087.3125 - val_mse: 317087.3125
# Epoch 16/20
# 69/69 [==============================] - 0s 2ms/step - loss: 270678.6562 - mse: 270678.6562 - val_loss: 322565.9375 - val_mse: 322565.9375
# Epoch 17/20
# 69/69 [==============================] - 0s 2ms/step - loss: 271751.8750 - mse: 271751.8750 - val_loss: 317850.9688 - val_mse: 317850.9688
# Epoch 18/20
# 69/69 [==============================] - 0s 3ms/step - loss: 271364.0938 - mse: 271364.0938 - val_loss: 315821.4062 - val_mse: 315821.4062
# Epoch 19/20
# 69/69 [==============================] - 0s 3ms/step - loss: 270514.9688 - mse: 270514.9688 - val_loss: 313720.8125 - val_mse: 313720.8125
# Epoch 20/20
# 69/69 [==============================] - 0s 2ms/step - loss: 271551.0625 - mse: 271551.0625 - val_loss: 310867.5938 - val_mse: 310867.5938
# 2/2 [==============================] - 0s 9ms/step
# 0.15257864518294617
