# %% [markdown]
# <a href="https://colab.research.google.com/github/zw2788/MECE4520_project/blob/main/MECE_4520_LaptopPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Linear Rregression

# %% [markdown]
# Neural Network

# %%
from typing import Tuple
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set(font_scale=1.5)
sns.set_style("whitegrid", {'grid.linestyle':'--'})

import numpy as np
import pandas as pd

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/Laptop_Intel1012.csv")
data.head()
# Out:
#    laptop_ID Company             Product            TypeName  Inches  \
# 0        739    Dell       Inspiron 3567            Notebook    15.6
# 1        898    Asus  Rog GL753VD-GC082T              Gaming    17.3
# 2         45    Dell       Inspiron 7773  2 in 1 Convertible    17.3
# 3        399    Acer            Aspire 5            Notebook    15.6
# 4        476  Lenovo      Thinkpad T460s           Ultrabook    14.0
#
#                   ScreenResolution                          Cpu  \
# 0                         1366x768   Intel Core i5 7200U 2.5GHz
# 1                Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz
# 2  Full HD / Touchscreen 1920x1080   Intel Core i5 8250U 1.6GHz
# 3               IPS Panel 1366x768   Intel Core i5 8250U 1.6GHz
# 4     IPS Panel Quad HD+ 2560x1440   Intel Core i7 6600U 2.6GHz
#
#    CPU_benchmark   Ram  Ram_benchmark               Memory  Memory_benchmark  \
# 0           3397  12GB             12              1TB HDD             39.99
# 1           5092  12GB             12  128GB SSD + 1TB HDD             58.98
# 2           5901  12GB             12              1TB HDD             39.99
# 3           5901  12GB             12              1TB HDD             39.99
# 4           3474  12GB             12            256GB SSD             22.99
#
#                       Gpu  GPU_benchmark       OpSys  Weight  \
# 0   Intel HD Graphics 520            3.5  Windows 10   2.3kg
# 1      AMD Radeon R5 M430            3.1  Windows 10  1.90kg
# 2   Intel HD Graphics 520            3.5  Windows 10  1.86kg
# 3   Intel HD Graphics 520            3.5  Windows 10   1.2kg
# 4  Intel HD Graphics 6000            3.9       macOS  1.34kg
#
#    Weight_benchmark  Price_euros
# 0              2.30       418.64
# 1              1.90       817.95
# 2              1.86       469.00
# 3              1.20      1535.00
# 4              1.34       898.94

# %%
features = [
    "GPU_benchmark",
    "Memory_benchmark",
    "CPU_benchmark",
    "Weight_benchmark",
    "Ram_benchmark"

]
label = "Price_euros"

# train test split
X_raw, X_raw_test, Y, Y_test = train_test_split(data[features].values, data[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw)
X = scaler.transform(X_raw)
X_test = scaler.transform(X_raw_test)

# formatting
Y = Y.reshape((-1, 1))
Y_test = Y_test.reshape((-1, 1))

# %%
fig = plt.figure(figsize=(16,6))
axes = fig.add_subplot(1, 1, 1)
axes.plot(X, Y, 'ro')
axes.set_xlabel('x')
axes.set_ylabel('u_ture')
axes.grid()

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam


model=Sequential([
    Dense(units=25,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=15,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history = model.fit(
    x=X,
    y=Y,
    batch_size=32,
    epochs=20,
    validation_data=(X_test, Y_test),
    verbose=1,
    shuffle=True,
)
# Out:
# Epoch 1/20
# 26/26 [==============================] - 1s 9ms/step - loss: 1726441.7500 - mse: 1726441.7500 - val_loss: 1813527.7500 - val_mse: 1813527.7500
# Epoch 2/20
# 26/26 [==============================] - 0s 3ms/step - loss: 1699299.0000 - mse: 1699299.0000 - val_loss: 1708146.5000 - val_mse: 1708146.5000
# Epoch 3/20
# 26/26 [==============================] - 0s 4ms/step - loss: 1395570.2500 - mse: 1395570.2500 - val_loss: 994310.3750 - val_mse: 994310.3750
# Epoch 4/20
# 26/26 [==============================] - 0s 4ms/step - loss: 580913.0000 - mse: 580913.0000 - val_loss: 398260.2812 - val_mse: 398260.2812
# Epoch 5/20
# 26/26 [==============================] - 0s 4ms/step - loss: 295995.1562 - mse: 295995.1562 - val_loss: 328082.9062 - val_mse: 328082.9062
# Epoch 6/20
# 26/26 [==============================] - 0s 3ms/step - loss: 251631.6406 - mse: 251631.6406 - val_loss: 277882.4062 - val_mse: 277882.4062
# Epoch 7/20
# 26/26 [==============================] - 0s 4ms/step - loss: 226847.3281 - mse: 226847.3281 - val_loss: 253757.2031 - val_mse: 253757.2031
# Epoch 8/20
# 26/26 [==============================] - 0s 3ms/step - loss: 210915.5781 - mse: 210915.5781 - val_loss: 235927.9844 - val_mse: 235927.9844
# Epoch 9/20
# 26/26 [==============================] - 0s 3ms/step - loss: 201236.1875 - mse: 201236.1875 - val_loss: 221049.4062 - val_mse: 221049.4062
# Epoch 10/20
# 26/26 [==============================] - 0s 3ms/step - loss: 194745.0312 - mse: 194745.0312 - val_loss: 215646.3438 - val_mse: 215646.3438
# Epoch 11/20
# 26/26 [==============================] - 0s 3ms/step - loss: 190373.1875 - mse: 190373.1875 - val_loss: 207654.7188 - val_mse: 207654.7188
# Epoch 12/20
# 26/26 [==============================] - 0s 4ms/step - loss: 188727.2812 - mse: 188727.2812 - val_loss: 207672.7344 - val_mse: 207672.7344
# Epoch 13/20
# 26/26 [==============================] - 0s 3ms/step - loss: 186407.9375 - mse: 186407.9375 - val_loss: 203861.1094 - val_mse: 203861.1094
# Epoch 14/20
# 26/26 [==============================] - 0s 3ms/step - loss: 185622.9688 - mse: 185622.9688 - val_loss: 197984.7031 - val_mse: 197984.7031
# Epoch 15/20
# 26/26 [==============================] - 0s 4ms/step - loss: 184919.4531 - mse: 184919.4531 - val_loss: 200987.2188 - val_mse: 200987.2188
# Epoch 16/20
# 26/26 [==============================] - 0s 4ms/step - loss: 183177.2812 - mse: 183177.2812 - val_loss: 195814.0625 - val_mse: 195814.0625
# Epoch 17/20
# 26/26 [==============================] - 0s 4ms/step - loss: 181075.8750 - mse: 181075.8750 - val_loss: 195072.2812 - val_mse: 195072.2812
# Epoch 18/20
# 26/26 [==============================] - 0s 4ms/step - loss: 180768.8906 - mse: 180768.8906 - val_loss: 192892.7031 - val_mse: 192892.7031
# Epoch 19/20
# 26/26 [==============================] - 0s 4ms/step - loss: 180972.3281 - mse: 180972.3281 - val_loss: 192246.0156 - val_mse: 192246.0156
# Epoch 20/20
# 26/26 [==============================] - 0s 3ms/step - loss: 180083.8438 - mse: 180083.8438 - val_loss: 192933.9062 - val_mse: 192933.9062

# %%
def plot_history(history, key):
  plt.plot(history.history[key])
  plt.plot(history.history['val_'+key])
  plt.xlabel("Epochs")
  plt.ylabel(key)
  plt.legend([key, 'val_'+key])
  plt.show()
# Plot the history
plot_history(history, 'mse')

# %%
yhat= model.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
r2 = np.power(yhat - np.mean(Y_test), 2).sum() / np.power(Y_test - np.mean(Y_test), 2).sum()
r2
# Out:
# 0.6713550166833017

# %% [markdown]
# GPU_NV

# %%
GPU_NV=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/NV.csv")
GPU_NV.head()
# Out:
#    laptop_ID Company             Product TypeName  Inches  \
# 0        151     MSI         GE72MVR 7RG   Gaming    17.3
# 1       1232    Asus           ROG Strix   Gaming    17.3
# 2       1251     MSI       GE72VR Apache   Gaming    17.3
# 3        306    Asus  Rog GL702VS-GC095T   Gaming    17.3
# 4        584  Lenovo  IdeaPad Y910-17ISK   Gaming    17.3
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 1            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 2            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 4  IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz           6933
#
#     Ram               Memory  Memory_benchmark                   Gpu  \
# 0  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 1  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 2  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 3  16GB  256GB SSD + 1TB HDD             69.98    Nvidia GeForce 920
# 4  32GB  256GB SSD + 1TB HDD             69.98   Nvidia GeForce 920M
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            6.5  Windows 10   2.1kg      1145.00
# 1            6.5  Windows 10  2.77kg       999.00
# 2            6.5  Windows 10  2.77kg      1549.00
# 3            3.6       Linux   2.1kg       519.00
# 4            3.6  Windows 10   2.2kg       720.32

# %%
features_GPU_NV = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_NV, X_raw_test_GPU_NV, Y_GPU_NV, Y_test_GPU_NV = train_test_split(GPU_NV[features_GPU_NV].values, GPU_NV[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_NV)
X_GPU_NV = scaler.transform(X_raw_GPU_NV)
X_test_GPU_NV = scaler.transform(X_raw_test_GPU_NV)

# formatting
Y_GPU_NV = Y_GPU_NV.reshape((-1, 1))
Y_test_GPU_NV = Y_test_GPU_NV.reshape((-1, 1))

model_GPU_NV=Sequential([
    Dense(units=25,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=15,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_NV.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_NV = model_GPU_NV.fit(
    x=X_GPU_NV,
    y=Y_GPU_NV,
    batch_size=16,
    epochs=20,
    validation_data=(X_test_GPU_NV, Y_test_GPU_NV),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_NV, 'mse')
yhat_GPU_NV= model_GPU_NV.predict(X_test_GPU_NV)

r2_GPU_NV = np.power(yhat_GPU_NV - np.mean(Y_test_GPU_NV), 2).sum() / np.power(Y_test_GPU_NV - np.mean(Y_test_GPU_NV), 2).sum()
r2_GPU_NV
# Out:
# Epoch 1/20
# 14/14 [==============================] - 1s 13ms/step - loss: 2971264.5000 - mse: 2971264.5000 - val_loss: 3217031.7500 - val_mse: 3217031.7500
# Epoch 2/20
# 14/14 [==============================] - 0s 4ms/step - loss: 2967607.7500 - mse: 2967607.7500 - val_loss: 3206341.0000 - val_mse: 3206341.0000
# Epoch 3/20
# 14/14 [==============================] - 0s 4ms/step - loss: 2936932.5000 - mse: 2936932.5000 - val_loss: 3137583.5000 - val_mse: 3137583.5000
# Epoch 4/20
# 14/14 [==============================] - 0s 6ms/step - loss: 2789948.5000 - mse: 2789948.5000 - val_loss: 2864601.5000 - val_mse: 2864601.5000
# Epoch 5/20
# 14/14 [==============================] - 0s 5ms/step - loss: 2347738.7500 - mse: 2347738.7500 - val_loss: 2149813.7500 - val_mse: 2149813.7500
# Epoch 6/20
# 14/14 [==============================] - 0s 6ms/step - loss: 1395400.0000 - mse: 1395400.0000 - val_loss: 998083.1250 - val_mse: 998083.1250
# Epoch 7/20
# 14/14 [==============================] - 0s 4ms/step - loss: 544767.7500 - mse: 544767.7500 - val_loss: 414866.6250 - val_mse: 414866.6250
# Epoch 8/20
# 14/14 [==============================] - 0s 5ms/step - loss: 319559.6250 - mse: 319559.6250 - val_loss: 322832.6875 - val_mse: 322832.6875
# Epoch 9/20
# 14/14 [==============================] - 0s 5ms/step - loss: 273049.8438 - mse: 273049.8438 - val_loss: 323162.6562 - val_mse: 323162.6562
# Epoch 10/20
# 14/14 [==============================] - 0s 5ms/step - loss: 274710.8438 - mse: 274710.8438 - val_loss: 316219.5938 - val_mse: 316219.5938
# Epoch 11/20
# 14/14 [==============================] - 0s 5ms/step - loss: 272966.1250 - mse: 272966.1250 - val_loss: 318792.7188 - val_mse: 318792.7188
# Epoch 12/20
# 14/14 [==============================] - 0s 4ms/step - loss: 273246.8125 - mse: 273246.8125 - val_loss: 313365.0938 - val_mse: 313365.0938
# Epoch 13/20
# 14/14 [==============================] - 0s 4ms/step - loss: 272918.9062 - mse: 272918.9062 - val_loss: 329830.7500 - val_mse: 329830.7500
# Epoch 14/20
# 14/14 [==============================] - 0s 4ms/step - loss: 274790.5000 - mse: 274790.5000 - val_loss: 311914.2500 - val_mse: 311914.2500
# Epoch 15/20
# 14/14 [==============================] - 0s 5ms/step - loss: 269378.4062 - mse: 269378.4062 - val_loss: 324550.3125 - val_mse: 324550.3125
# Epoch 16/20
# 14/14 [==============================] - 0s 4ms/step - loss: 269283.9375 - mse: 269283.9375 - val_loss: 318313.8438 - val_mse: 318313.8438
# Epoch 17/20
# 14/14 [==============================] - 0s 6ms/step - loss: 271179.5625 - mse: 271179.5625 - val_loss: 319986.6250 - val_mse: 319986.6250
# Epoch 18/20
# 14/14 [==============================] - 0s 5ms/step - loss: 270662.1250 - mse: 270662.1250 - val_loss: 314691.9375 - val_mse: 314691.9375
# Epoch 19/20
# 14/14 [==============================] - 0s 5ms/step - loss: 269361.8438 - mse: 269361.8438 - val_loss: 320675.4062 - val_mse: 320675.4062
# Epoch 20/20
# 14/14 [==============================] - 0s 5ms/step - loss: 272458.4062 - mse: 272458.4062 - val_loss: 314516.4375 - val_mse: 314516.4375
# 2/2 [==============================] - 0s 7ms/step
# 0.40557968788281146

# %% [markdown]
# GPU_AMD

# %%
GPU_AMD=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/NV.csv")
GPU_AMD.head()
# Out:
#    laptop_ID Company             Product TypeName  Inches  \
# 0        151     MSI         GE72MVR 7RG   Gaming    17.3
# 1       1232    Asus           ROG Strix   Gaming    17.3
# 2       1251     MSI       GE72VR Apache   Gaming    17.3
# 3        306    Asus  Rog GL702VS-GC095T   Gaming    17.3
# 4        584  Lenovo  IdeaPad Y910-17ISK   Gaming    17.3
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 1            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 2            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 4  IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz           6933
#
#     Ram               Memory  Memory_benchmark                   Gpu  \
# 0  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 1  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 2  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 3  16GB  256GB SSD + 1TB HDD             69.98    Nvidia GeForce 920
# 4  32GB  256GB SSD + 1TB HDD             69.98   Nvidia GeForce 920M
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            6.5  Windows 10   2.1kg      1145.00
# 1            6.5  Windows 10  2.77kg       999.00
# 2            6.5  Windows 10  2.77kg      1549.00
# 3            3.6       Linux   2.1kg       519.00
# 4            3.6  Windows 10   2.2kg       720.32

# %%
features_GPU_AMD = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_AMD, X_raw_test_GPU_AMD, Y_GPU_AMD, Y_test_GPU_AMD = train_test_split(GPU_AMD[features_GPU_AMD].values, GPU_AMD[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_AMD)
X_GPU_AMD = scaler.transform(X_raw_GPU_AMD)
X_test_GPU_AMD = scaler.transform(X_raw_test_GPU_AMD)

# formatting
Y_GPU_AMD = Y_GPU_AMD.reshape((-1, 1))
Y_test_GPU_AMD = Y_test_GPU_AMD.reshape((-1, 1))

model_GPU_AMD=Sequential([
    Dense(units=25,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=10,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_AMD.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_AMD = model_GPU_AMD.fit(
    x=X_GPU_AMD,
    y=Y_GPU_AMD,
    batch_size=8,
    epochs=20,
    validation_data=(X_test_GPU_AMD, Y_test_GPU_AMD),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_AMD, 'mse')
yhat_GPU_AMD= model_GPU_AMD.predict(X_test_GPU_AMD)

r2_GPU_AMD = np.power(yhat_GPU_AMD - np.mean(Y_test_GPU_AMD), 2).sum() / np.power(Y_test_GPU_AMD - np.mean(Y_test_GPU_AMD), 2).sum()
r2_GPU_AMD
# Out:
# Epoch 1/20
# 28/28 [==============================] - 1s 8ms/step - loss: 2970937.5000 - mse: 2970937.5000 - val_loss: 3215805.7500 - val_mse: 3215805.7500
# Epoch 2/20
# 28/28 [==============================] - 0s 3ms/step - loss: 2958148.7500 - mse: 2958148.7500 - val_loss: 3174254.5000 - val_mse: 3174254.5000
# Epoch 3/20
# 28/28 [==============================] - 0s 3ms/step - loss: 2825306.7500 - mse: 2825306.7500 - val_loss: 2855521.7500 - val_mse: 2855521.7500
# Epoch 4/20
# 28/28 [==============================] - 0s 4ms/step - loss: 2200814.0000 - mse: 2200814.0000 - val_loss: 1806866.7500 - val_mse: 1806866.6250
# Epoch 5/20
# 28/28 [==============================] - 0s 3ms/step - loss: 991842.3750 - mse: 991842.3750 - val_loss: 638000.4375 - val_mse: 638000.4375
# Epoch 6/20
# 28/28 [==============================] - 0s 3ms/step - loss: 383345.8438 - mse: 383345.8438 - val_loss: 369449.2500 - val_mse: 369449.2500
# Epoch 7/20
# 28/28 [==============================] - 0s 3ms/step - loss: 277934.8125 - mse: 277934.8125 - val_loss: 325992.8438 - val_mse: 325992.8438
# Epoch 8/20
# 28/28 [==============================] - 0s 3ms/step - loss: 270173.9375 - mse: 270173.9375 - val_loss: 320973.3125 - val_mse: 320973.3125
# Epoch 9/20
# 28/28 [==============================] - 0s 3ms/step - loss: 271149.5938 - mse: 271149.5938 - val_loss: 317946.2188 - val_mse: 317946.2188
# Epoch 10/20
# 28/28 [==============================] - 0s 4ms/step - loss: 271405.6250 - mse: 271405.6250 - val_loss: 316966.9062 - val_mse: 316966.9062
# Epoch 11/20
# 28/28 [==============================] - 0s 3ms/step - loss: 271418.5312 - mse: 271418.5312 - val_loss: 316183.0625 - val_mse: 316183.0625
# Epoch 12/20
# 28/28 [==============================] - 0s 3ms/step - loss: 271394.9375 - mse: 271394.9375 - val_loss: 317576.5312 - val_mse: 317576.5312
# Epoch 13/20
# 28/28 [==============================] - 0s 3ms/step - loss: 270315.4688 - mse: 270315.4688 - val_loss: 316532.0000 - val_mse: 316532.0000
# Epoch 14/20
# 28/28 [==============================] - 0s 3ms/step - loss: 275693.8125 - mse: 275693.8125 - val_loss: 325028.9375 - val_mse: 325028.9375
# Epoch 15/20
# 28/28 [==============================] - 0s 5ms/step - loss: 270955.7188 - mse: 270955.7188 - val_loss: 312985.3750 - val_mse: 312985.3750
# Epoch 16/20
# 28/28 [==============================] - 0s 4ms/step - loss: 270717.8438 - mse: 270717.8438 - val_loss: 323992.6562 - val_mse: 323992.6562
# Epoch 17/20
# 28/28 [==============================] - 0s 3ms/step - loss: 272739.7812 - mse: 272739.7812 - val_loss: 314699.5625 - val_mse: 314699.5625
# Epoch 18/20
# 28/28 [==============================] - 0s 3ms/step - loss: 269544.6562 - mse: 269544.6562 - val_loss: 323572.9688 - val_mse: 323572.9688
# Epoch 19/20
# 28/28 [==============================] - 0s 4ms/step - loss: 271493.6250 - mse: 271493.6250 - val_loss: 320436.6562 - val_mse: 320436.6562
# Epoch 20/20
# 28/28 [==============================] - 0s 4ms/step - loss: 270651.0938 - mse: 270651.0938 - val_loss: 314640.2500 - val_mse: 314640.2500
# 2/2 [==============================] - 0s 6ms/step
# 0.42141446564144647

# %%
GPU_Intel
# Out:
#      laptop_ID Company            Product  TypeName  Inches  \
# 0         1274    Asus  Rog G752VT-GC073T    Gaming    17.3
# 1          286    Dell      Inspiron 3567  Notebook    15.6
# 2          897    Dell        Vostro 3568  Notebook    15.6
# 3          910    Dell        Vostro 3568  Notebook    15.6
# 4          979    Dell      Inspiron 3567  Notebook    15.6
# ..         ...     ...                ...       ...     ...
# 608        471  Lenovo       Thinkpad P51  Notebook    15.6
# 609         52    Acer    Aspire A515-51G  Notebook    15.6
# 610        120    Dell      Inspiron 7570  Notebook    15.6
# 611        289    Acer    Aspire A517-51G  Notebook    15.6
# 612        521  Xiaomi        Mi Notebook  Notebook    15.6
#
#                 ScreenResolution                          Cpu  CPU_Benchmark  \
# 0    IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz           6528
# 1              Full HD 1920x1080   Intel Core i3 6006U 2.0GHz           2273
# 2                       1366x768   Intel Core i3 6006U 2.0GHz           2273
# 3                       1366x768   Intel Core i3 6006U 2.0GHz           2273
# 4                       1366x768   Intel Core i3 6006U 2.0GHz           2273
# ..                           ...                          ...            ...
# 608            Full HD 1920x1080  Intel Core i7 7820HQ 2.9GHz           7140
# 609  IPS Panel Full HD 1920x1080   Intel Core i7 8550U 1.8GHz           5951
# 610  IPS Panel Full HD 1920x1080   Intel Core i7 8550U 1.8GHz           5951
# 611  IPS Panel Full HD 1920x1080   Intel Core i7 8550U 1.8GHz           5951
# 612  IPS Panel Full HD 1920x1080   Intel Core i7 8550U 1.8GHz           5951
#
#       Ram               Memory  Memory_benchmark                     Gpu  \
# 0    16GB  128GB SSD + 1TB HDD             58.98      Intel Graphics 620
# 1     4GB              1TB HDD             39.99   Intel HD Graphics 400
# 2     4GB              1TB HDD             39.99   Intel HD Graphics 400
# 3     4GB              1TB HDD             39.99   Intel HD Graphics 400
# 4     4GB              1TB HDD             39.99   Intel HD Graphics 400
# ..    ...                  ...               ...                     ...
# 608   8GB            256GB SSD             22.99  Intel UHD Graphics 620
# 609   8GB            256GB SSD             22.99  Intel UHD Graphics 620
# 610   8GB  256GB SSD + 1TB HDD             69.98  Intel UHD Graphics 620
# 611   8GB            256GB SSD             22.99  Intel UHD Graphics 620
# 612  16GB            256GB SSD             22.99  Intel UHD Graphics 620
#
#      GPU_benchmark       OpSys  Weight  Price_euros
# 0              3.9  Windows 10   1.8kg       919.00
# 1              1.1   Chrome OS  1.25kg       389.00
# 2              1.1   Chrome OS   1.5kg       325.00
# 3              1.1       No OS  1.86kg       299.00
# 4              1.1     Android  0.69kg       549.00
# ..             ...         ...     ...          ...
# 608            4.4  Windows 10  1.56kg      1049.00
# 609            4.4  Windows 10  1.88kg      1298.00
# 610            4.4  Windows 10  1.49kg       675.00
# 611            4.4  Windows 10  1.88kg      1096.16
# 612            4.4  Windows 10  1.21kg      1649.00
#
# [613 rows x 16 columns]

# %%
GPU_Intel=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/Intel.csv")
GPU_Intel.head()
# Out:
#    laptop_ID Company            Product  TypeName  Inches  \
# 0       1274    Asus  Rog G752VT-GC073T    Gaming    17.3
# 1        286    Dell      Inspiron 3567  Notebook    15.6
# 2        897    Dell        Vostro 3568  Notebook    15.6
# 3        910    Dell        Vostro 3568  Notebook    15.6
# 4        979    Dell      Inspiron 3567  Notebook    15.6
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0  IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz           6528
# 1            Full HD 1920x1080   Intel Core i3 6006U 2.0GHz           2273
# 2                     1366x768   Intel Core i3 6006U 2.0GHz           2273
# 3                     1366x768   Intel Core i3 6006U 2.0GHz           2273
# 4                     1366x768   Intel Core i3 6006U 2.0GHz           2273
#
#     Ram               Memory  Memory_benchmark                    Gpu  \
# 0  16GB  128GB SSD + 1TB HDD             58.98     Intel Graphics 620
# 1   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 2   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 3   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 4   4GB              1TB HDD             39.99  Intel HD Graphics 400
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            3.9  Windows 10   1.8kg        919.0
# 1            1.1   Chrome OS  1.25kg        389.0
# 2            1.1   Chrome OS   1.5kg        325.0
# 3            1.1       No OS  1.86kg        299.0
# 4            1.1     Android  0.69kg        549.0

# %%
features_GPU_Intel = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_Intel, X_raw_test_GPU_Intel, Y_GPU_Intel, Y_test_GPU_Intel = train_test_split(GPU_Intel[features_GPU_Intel].values, GPU_Intel[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_Intel)
X_GPU_Intel = scaler.transform(X_raw_GPU_Intel)
X_test_GPU_Intel = scaler.transform(X_raw_test_GPU_Intel)

# formatting
Y_GPU_Intel = Y_GPU_Intel.reshape((-1, 1))
Y_test_GPU_Intel = Y_test_GPU_Intel.reshape((-1, 1))

model_GPU_Intel=Sequential([
    Dense(units=15,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=8,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=3,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_Intel.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_Intel = model_GPU_Intel.fit(
    x=X_GPU_Intel,
    y=Y_GPU_Intel,
    batch_size=8,
    epochs=20,
    validation_data=(X_test_GPU_Intel, Y_test_GPU_Intel),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_Intel, 'mse')
yhat_GPU_Intel= model_GPU_Intel.predict(X_test_GPU_Intel)

r2_GPU_Intel = np.power(yhat_GPU_Intel - np.mean(Y_test_GPU_Intel), 2).sum() / np.power(Y_test_GPU_Intel - np.mean(Y_test_GPU_Intel), 2).sum()
r2_GPU_Intel
# Out:
# Epoch 1/20
# 62/62 [==============================] - 1s 5ms/step - loss: 1356880.7500 - mse: 1356880.7500 - val_loss: 1478519.8750 - val_mse: 1478519.8750
# Epoch 2/20
# 62/62 [==============================] - 0s 2ms/step - loss: 820848.2500 - mse: 820848.2500 - val_loss: 467827.9375 - val_mse: 467827.9375
# Epoch 3/20
# 62/62 [==============================] - 0s 2ms/step - loss: 284186.9062 - mse: 284186.9062 - val_loss: 382843.0312 - val_mse: 382843.0312
# Epoch 4/20
# 62/62 [==============================] - 0s 2ms/step - loss: 260843.1719 - mse: 260843.1719 - val_loss: 353464.0938 - val_mse: 353464.0938
# Epoch 5/20
# 62/62 [==============================] - 0s 2ms/step - loss: 258234.1406 - mse: 258234.1406 - val_loss: 349060.1562 - val_mse: 349060.1562
# Epoch 6/20
# 62/62 [==============================] - 0s 2ms/step - loss: 254310.4844 - mse: 254310.4844 - val_loss: 365398.5938 - val_mse: 365398.5938
# Epoch 7/20
# 62/62 [==============================] - 0s 3ms/step - loss: 261264.7188 - mse: 261264.7188 - val_loss: 351933.7812 - val_mse: 351933.7812
# Epoch 8/20
# 62/62 [==============================] - 0s 2ms/step - loss: 256861.5000 - mse: 256861.5000 - val_loss: 345601.9375 - val_mse: 345601.9375
# Epoch 9/20
# 62/62 [==============================] - 0s 2ms/step - loss: 256365.1094 - mse: 256365.1094 - val_loss: 362449.7500 - val_mse: 362449.7500
# Epoch 10/20
# 62/62 [==============================] - 0s 2ms/step - loss: 259997.7344 - mse: 259997.7344 - val_loss: 349672.9062 - val_mse: 349672.9062
# Epoch 11/20
# 62/62 [==============================] - 0s 3ms/step - loss: 256305.0000 - mse: 256305.0000 - val_loss: 348058.4062 - val_mse: 348058.4062
# Epoch 12/20
# 62/62 [==============================] - 0s 2ms/step - loss: 257693.5781 - mse: 257693.5781 - val_loss: 349997.5312 - val_mse: 349997.5312
# Epoch 13/20
# 62/62 [==============================] - 0s 2ms/step - loss: 257715.0000 - mse: 257715.0000 - val_loss: 342149.3125 - val_mse: 342149.3125
# Epoch 14/20
# 62/62 [==============================] - 0s 2ms/step - loss: 258582.1562 - mse: 258582.1562 - val_loss: 350915.3750 - val_mse: 350915.3750
# Epoch 15/20
# 62/62 [==============================] - 0s 2ms/step - loss: 257172.5938 - mse: 257172.5938 - val_loss: 353854.9688 - val_mse: 353854.9688
# Epoch 16/20
# 62/62 [==============================] - 0s 2ms/step - loss: 257347.8906 - mse: 257347.8906 - val_loss: 352867.5312 - val_mse: 352867.5312
# Epoch 17/20
# 62/62 [==============================] - 0s 3ms/step - loss: 257999.4844 - mse: 257999.4844 - val_loss: 352126.5938 - val_mse: 352126.5938
# Epoch 18/20
# 62/62 [==============================] - 0s 2ms/step - loss: 256766.3125 - mse: 256766.3125 - val_loss: 349167.6562 - val_mse: 349167.6562
# Epoch 19/20
# 62/62 [==============================] - 0s 2ms/step - loss: 256940.8281 - mse: 256940.8281 - val_loss: 348190.5000 - val_mse: 348190.5000
# Epoch 20/20
# 62/62 [==============================] - 0s 2ms/step - loss: 257344.6406 - mse: 257344.6406 - val_loss: 360987.0625 - val_mse: 360987.0625
# 4/4 [==============================] - 0s 3ms/step
# 0.17815081634410176
