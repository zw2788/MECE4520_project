# %% [markdown]
# <a href="https://colab.research.google.com/github/zw2788/MECE4520_project/blob/main/MECE_4520_LaptopPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Linear Rregression

# %% [markdown]
# Neural Network

# %%
from typing import Tuple
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set(font_scale=1.5)
sns.set_style("whitegrid", {'grid.linestyle':'--'})

import numpy as np
import pandas as pd

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/Laptop_Intel1012.csv")
data.head()
# Out:
#    laptop_ID Company             Product            TypeName  Inches  \
# 0        739    Dell       Inspiron 3567            Notebook    15.6
# 1        898    Asus  Rog GL753VD-GC082T              Gaming    17.3
# 2         45    Dell       Inspiron 7773  2 in 1 Convertible    17.3
# 3        399    Acer            Aspire 5            Notebook    15.6
# 4        476  Lenovo      Thinkpad T460s           Ultrabook    14.0
#
#                   ScreenResolution                          Cpu  \
# 0                         1366x768   Intel Core i5 7200U 2.5GHz
# 1                Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz
# 2  Full HD / Touchscreen 1920x1080   Intel Core i5 8250U 1.6GHz
# 3               IPS Panel 1366x768   Intel Core i5 8250U 1.6GHz
# 4     IPS Panel Quad HD+ 2560x1440   Intel Core i7 6600U 2.6GHz
#
#    CPU_benchmark   Ram  Ram_benchmark               Memory  Memory_benchmark  \
# 0           3397  12GB             12              1TB HDD             39.99
# 1           5092  12GB             12  128GB SSD + 1TB HDD             58.98
# 2           5901  12GB             12              1TB HDD             39.99
# 3           5901  12GB             12              1TB HDD             39.99
# 4           3474  12GB             12            256GB SSD             22.99
#
#                       Gpu  GPU_benchmark       OpSys  Weight  \
# 0   Intel HD Graphics 520            3.5  Windows 10   2.3kg
# 1      AMD Radeon R5 M430            3.1  Windows 10  1.90kg
# 2   Intel HD Graphics 520            3.5  Windows 10  1.86kg
# 3   Intel HD Graphics 520            3.5  Windows 10   1.2kg
# 4  Intel HD Graphics 6000            3.9       macOS  1.34kg
#
#    Weight_benchmark  Price_euros
# 0              2.30       418.64
# 1              1.90       817.95
# 2              1.86       469.00
# 3              1.20      1535.00
# 4              1.34       898.94

# %%
features = [
    "GPU_benchmark",
    "Memory_benchmark",
    "CPU_benchmark",
    "Weight_benchmark",
    "Ram_benchmark"

]
label = "Price_euros"

# train test split
X_raw, X_raw_test, Y, Y_test = train_test_split(data[features].values, data[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw)
X = scaler.transform(X_raw)
X_test = scaler.transform(X_raw_test)

# formatting
Y = Y.reshape((-1, 1))
Y_test = Y_test.reshape((-1, 1))

# %%
fig = plt.figure(figsize=(16,6))
axes = fig.add_subplot(1, 1, 1)
axes.plot(X, Y, 'ro')
axes.set_xlabel('x')
axes.set_ylabel('u_ture')
axes.grid()

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam


model=Sequential([
    Dense(units=50,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=20,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history = model.fit(
    x=X,
    y=Y,
    batch_size=32,
    epochs=20,
    validation_data=(X_test, Y_test),
    verbose=1,
    shuffle=True,
)
# Out:
# Epoch 1/20
# 26/26 [==============================] - 1s 9ms/step - loss: 1726001.8750 - mse: 1726001.8750 - val_loss: 1809834.2500 - val_mse: 1809834.2500
# Epoch 2/20
# 26/26 [==============================] - 0s 5ms/step - loss: 1661379.1250 - mse: 1661379.1250 - val_loss: 1563071.2500 - val_mse: 1563071.2500
# Epoch 3/20
# 26/26 [==============================] - 0s 4ms/step - loss: 1011261.3125 - mse: 1011261.3125 - val_loss: 448881.8438 - val_mse: 448881.8438
# Epoch 4/20
# 26/26 [==============================] - 0s 3ms/step - loss: 335134.8125 - mse: 335134.8125 - val_loss: 319853.0000 - val_mse: 319853.0000
# Epoch 5/20
# 26/26 [==============================] - 0s 4ms/step - loss: 247791.0781 - mse: 247791.0781 - val_loss: 271208.0312 - val_mse: 271208.0312
# Epoch 6/20
# 26/26 [==============================] - 0s 3ms/step - loss: 227563.5938 - mse: 227563.5938 - val_loss: 243536.0000 - val_mse: 243536.0000
# Epoch 7/20
# 26/26 [==============================] - 0s 3ms/step - loss: 208457.0000 - mse: 208457.0000 - val_loss: 231185.5156 - val_mse: 231185.5156
# Epoch 8/20
# 26/26 [==============================] - 0s 3ms/step - loss: 200461.2969 - mse: 200461.2969 - val_loss: 218146.6406 - val_mse: 218146.6406
# Epoch 9/20
# 26/26 [==============================] - 0s 3ms/step - loss: 193851.0625 - mse: 193851.0625 - val_loss: 211863.6406 - val_mse: 211863.6406
# Epoch 10/20
# 26/26 [==============================] - 0s 3ms/step - loss: 190563.0000 - mse: 190563.0000 - val_loss: 205364.0156 - val_mse: 205364.0156
# Epoch 11/20
# 26/26 [==============================] - 0s 4ms/step - loss: 187368.9219 - mse: 187368.9219 - val_loss: 204272.3906 - val_mse: 204272.3906
# Epoch 12/20
# 26/26 [==============================] - 0s 4ms/step - loss: 185710.7188 - mse: 185710.7188 - val_loss: 199697.8125 - val_mse: 199697.8125
# Epoch 13/20
# 26/26 [==============================] - 0s 4ms/step - loss: 184151.0000 - mse: 184151.0000 - val_loss: 196958.9688 - val_mse: 196958.9688
# Epoch 14/20
# 26/26 [==============================] - 0s 4ms/step - loss: 185134.0938 - mse: 185134.0938 - val_loss: 195725.4844 - val_mse: 195725.4844
# Epoch 15/20
# 26/26 [==============================] - 0s 4ms/step - loss: 183086.6875 - mse: 183086.6875 - val_loss: 193188.2344 - val_mse: 193188.2344
# Epoch 16/20
# 26/26 [==============================] - 0s 4ms/step - loss: 181942.6250 - mse: 181942.6250 - val_loss: 193376.3125 - val_mse: 193376.3125
# Epoch 17/20
# 26/26 [==============================] - 0s 4ms/step - loss: 182770.9844 - mse: 182770.9844 - val_loss: 190593.9688 - val_mse: 190593.9688
# Epoch 18/20
# 26/26 [==============================] - 0s 4ms/step - loss: 180236.7500 - mse: 180236.7500 - val_loss: 192005.9688 - val_mse: 192005.9688
# Epoch 19/20
# 26/26 [==============================] - 0s 4ms/step - loss: 181569.0625 - mse: 181569.0625 - val_loss: 191023.3281 - val_mse: 191023.3281
# Epoch 20/20
# 26/26 [==============================] - 0s 4ms/step - loss: 180544.2031 - mse: 180544.2031 - val_loss: 194855.2969 - val_mse: 194855.2969

# %%
def plot_history(history, key):
  plt.plot(history.history[key])
  plt.plot(history.history['val_'+key])
  plt.xlabel("Epochs")
  plt.ylabel(key)
  plt.legend([key, 'val_'+key])
  plt.show()
# Plot the history
plot_history(history, 'mse')

# %%
yhat= model.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
r2 = np.power(yhat - np.mean(Y_test), 2).sum() / np.power(Y_test - np.mean(Y_test), 2).sum()
r2
# Out:
# 0.7117596641208151

# %% [markdown]
# GPU_NV

# %%
GPU_NV=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/NV.csv")
GPU_NV.head()
# Out:
#    laptop_ID Company             Product TypeName  Inches  \
# 0        151     MSI         GE72MVR 7RG   Gaming    17.3
# 1       1232    Asus           ROG Strix   Gaming    17.3
# 2       1251     MSI       GE72VR Apache   Gaming    17.3
# 3        306    Asus  Rog GL702VS-GC095T   Gaming    17.3
# 4        584  Lenovo  IdeaPad Y910-17ISK   Gaming    17.3
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 1            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 2            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 4  IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz           6933
#
#     Ram               Memory  Memory_benchmark                   Gpu  \
# 0  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 1  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 2  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 3  16GB  256GB SSD + 1TB HDD             69.98    Nvidia GeForce 920
# 4  32GB  256GB SSD + 1TB HDD             69.98   Nvidia GeForce 920M
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            6.5  Windows 10   2.1kg      1145.00
# 1            6.5  Windows 10  2.77kg       999.00
# 2            6.5  Windows 10  2.77kg      1549.00
# 3            3.6       Linux   2.1kg       519.00
# 4            3.6  Windows 10   2.2kg       720.32

# %%
features_GPU_NV = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_NV, X_raw_test_GPU_NV, Y_GPU_NV, Y_test_GPU_NV = train_test_split(GPU_NV[features_GPU_NV].values, GPU_NV[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_NV)
X_GPU_NV = scaler.transform(X_raw_GPU_NV)
X_test_GPU_NV = scaler.transform(X_raw_test_GPU_NV)

# formatting
Y_GPU_NV = Y_GPU_NV.reshape((-1, 1))
Y_test_GPU_NV = Y_test_GPU_NV.reshape((-1, 1))

model_GPU_NV=Sequential([
    Dense(units=25,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=15,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_NV.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_NV = model_GPU_NV.fit(
    x=X_GPU_NV,
    y=Y_GPU_NV,
    batch_size=16,
    epochs=20,
    validation_data=(X_test_GPU_NV, Y_test_GPU_NV),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_NV, 'mse')
yhat_GPU_NV= model_GPU_NV.predict(X_test_GPU_NV)

r2_GPU_NV = np.power(yhat_GPU_NV - np.mean(Y_test_GPU_NV), 2).sum() / np.power(Y_test_GPU_NV - np.mean(Y_test_GPU_NV), 2).sum()
r2_GPU_NV
# Out:
# Epoch 1/20
# 14/14 [==============================] - 1s 17ms/step - loss: 2971385.0000 - mse: 2971385.0000 - val_loss: 3217596.2500 - val_mse: 3217596.2500
# Epoch 2/20
# 14/14 [==============================] - 0s 5ms/step - loss: 2970634.2500 - mse: 2970634.2500 - val_loss: 3216244.2500 - val_mse: 3216244.2500
# Epoch 3/20
# 14/14 [==============================] - 0s 6ms/step - loss: 2967873.5000 - mse: 2967873.5000 - val_loss: 3210476.0000 - val_mse: 3210476.0000
# Epoch 4/20
# 14/14 [==============================] - 0s 5ms/step - loss: 2956916.2500 - mse: 2956916.2500 - val_loss: 3189277.5000 - val_mse: 3189277.5000
# Epoch 5/20
# 14/14 [==============================] - 0s 5ms/step - loss: 2920320.5000 - mse: 2920320.5000 - val_loss: 3126524.0000 - val_mse: 3126524.0000
# Epoch 6/20
# 14/14 [==============================] - 0s 6ms/step - loss: 2822236.5000 - mse: 2822236.5000 - val_loss: 2972329.0000 - val_mse: 2972329.0000
# Epoch 7/20
# 14/14 [==============================] - 0s 6ms/step - loss: 2610202.5000 - mse: 2610202.5000 - val_loss: 2662956.7500 - val_mse: 2662956.7500
# Epoch 8/20
# 14/14 [==============================] - 0s 5ms/step - loss: 2207103.0000 - mse: 2207103.0000 - val_loss: 2156087.7500 - val_mse: 2156087.7500
# Epoch 9/20
# 14/14 [==============================] - 0s 6ms/step - loss: 1642887.8750 - mse: 1642887.8750 - val_loss: 1498225.6250 - val_mse: 1498225.6250
# Epoch 10/20
# 14/14 [==============================] - 0s 4ms/step - loss: 1020201.3750 - mse: 1020201.3750 - val_loss: 942643.1875 - val_mse: 942643.1875
# Epoch 11/20
# 14/14 [==============================] - 0s 4ms/step - loss: 611885.5000 - mse: 611885.5000 - val_loss: 617208.5000 - val_mse: 617208.5000
# Epoch 12/20
# 14/14 [==============================] - 0s 6ms/step - loss: 400717.4062 - mse: 400717.4062 - val_loss: 448701.8438 - val_mse: 448701.8438
# Epoch 13/20
# 14/14 [==============================] - 0s 4ms/step - loss: 314866.2188 - mse: 314866.2188 - val_loss: 357137.9062 - val_mse: 357137.9062
# Epoch 14/20
# 14/14 [==============================] - 0s 5ms/step - loss: 278310.2188 - mse: 278310.2188 - val_loss: 327144.6562 - val_mse: 327144.6562
# Epoch 15/20
# 14/14 [==============================] - 0s 4ms/step - loss: 269518.1875 - mse: 269518.1875 - val_loss: 320571.7500 - val_mse: 320571.7500
# Epoch 16/20
# 14/14 [==============================] - 0s 5ms/step - loss: 269375.8750 - mse: 269375.8750 - val_loss: 319447.4062 - val_mse: 319447.4062
# Epoch 17/20
# 14/14 [==============================] - 0s 4ms/step - loss: 269646.2188 - mse: 269646.2188 - val_loss: 316124.9062 - val_mse: 316124.9062
# Epoch 18/20
# 14/14 [==============================] - 0s 5ms/step - loss: 269938.7500 - mse: 269938.7500 - val_loss: 321609.1250 - val_mse: 321609.1250
# Epoch 19/20
# 14/14 [==============================] - 0s 5ms/step - loss: 270065.5000 - mse: 270065.5000 - val_loss: 321147.1250 - val_mse: 321147.1250
# Epoch 20/20
# 14/14 [==============================] - 0s 6ms/step - loss: 268562.2812 - mse: 268562.2812 - val_loss: 317472.6875 - val_mse: 317472.6875
# 2/2 [==============================] - 0s 6ms/step
# 0.4063383070536465

# %% [markdown]
# GPU_AMD

# %%
GPU_AMD=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/NV.csv")
GPU_AMD.head()
# Out:
#    laptop_ID Company             Product TypeName  Inches  \
# 0        151     MSI         GE72MVR 7RG   Gaming    17.3
# 1       1232    Asus           ROG Strix   Gaming    17.3
# 2       1251     MSI       GE72VR Apache   Gaming    17.3
# 3        306    Asus  Rog GL702VS-GC095T   Gaming    17.3
# 4        584  Lenovo  IdeaPad Y910-17ISK   Gaming    17.3
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 1            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 2            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 4  IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz           6933
#
#     Ram               Memory  Memory_benchmark                   Gpu  \
# 0  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 1  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 2  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 3  16GB  256GB SSD + 1TB HDD             69.98    Nvidia GeForce 920
# 4  32GB  256GB SSD + 1TB HDD             69.98   Nvidia GeForce 920M
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            6.5  Windows 10   2.1kg      1145.00
# 1            6.5  Windows 10  2.77kg       999.00
# 2            6.5  Windows 10  2.77kg      1549.00
# 3            3.6       Linux   2.1kg       519.00
# 4            3.6  Windows 10   2.2kg       720.32

# %%
features_GPU_AMD = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_AMD, X_raw_test_GPU_AMD, Y_GPU_AMD, Y_test_GPU_AMD = train_test_split(GPU_AMD[features_GPU_AMD].values, GPU_AMD[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_AMD)
X_GPU_AMD = scaler.transform(X_raw_GPU_AMD)
X_test_GPU_AMD = scaler.transform(X_raw_test_GPU_AMD)

# formatting
Y_GPU_AMD = Y_GPU_AMD.reshape((-1, 1))
Y_test_GPU_AMD = Y_test_GPU_AMD.reshape((-1, 1))

model_GPU_AMD=Sequential([
    Dense(units=25,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=10,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_AMD.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_AMD = model_GPU_AMD.fit(
    x=X_GPU_AMD,
    y=Y_GPU_AMD,
    batch_size=8,
    epochs=20,
    validation_data=(X_test_GPU_AMD, Y_test_GPU_AMD),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_AMD, 'mse')
yhat_GPU_AMD= model_GPU_AMD.predict(X_test_GPU_AMD)

r2_GPU_AMD = np.power(yhat_GPU_AMD - np.mean(Y_test_GPU_AMD), 2).sum() / np.power(Y_test_GPU_AMD - np.mean(Y_test_GPU_AMD), 2).sum()
r2_GPU_AMD
# Out:
# Epoch 1/20
# 28/28 [==============================] - 1s 9ms/step - loss: 2970456.2500 - mse: 2970456.2500 - val_loss: 3212409.2500 - val_mse: 3212409.2500
# Epoch 2/20
# 28/28 [==============================] - 0s 4ms/step - loss: 2916061.2500 - mse: 2916061.2500 - val_loss: 3021088.2500 - val_mse: 3021088.2500
# Epoch 3/20
# 28/28 [==============================] - 0s 4ms/step - loss: 2319618.7500 - mse: 2319618.7500 - val_loss: 1706256.6250 - val_mse: 1706256.6250
# Epoch 4/20
# 28/28 [==============================] - 0s 4ms/step - loss: 750361.1250 - mse: 750361.1250 - val_loss: 489339.5000 - val_mse: 489339.5000
# Epoch 5/20
# 28/28 [==============================] - 0s 3ms/step - loss: 326378.9375 - mse: 326378.9375 - val_loss: 308269.8125 - val_mse: 308269.8125
# Epoch 6/20
# 28/28 [==============================] - 0s 3ms/step - loss: 271280.3125 - mse: 271280.3125 - val_loss: 319442.1875 - val_mse: 319442.1875
# Epoch 7/20
# 28/28 [==============================] - 0s 4ms/step - loss: 271914.0938 - mse: 271914.0938 - val_loss: 322526.5312 - val_mse: 322526.5312
# Epoch 8/20
# 28/28 [==============================] - 0s 3ms/step - loss: 268666.2188 - mse: 268666.2188 - val_loss: 314636.0000 - val_mse: 314636.0000
# Epoch 9/20
# 28/28 [==============================] - 0s 3ms/step - loss: 269983.9062 - mse: 269983.9062 - val_loss: 313189.7812 - val_mse: 313189.7812
# Epoch 10/20
# 28/28 [==============================] - 0s 3ms/step - loss: 270898.6875 - mse: 270898.6875 - val_loss: 320631.4062 - val_mse: 320631.4062
# Epoch 11/20
# 28/28 [==============================] - 0s 4ms/step - loss: 274460.8750 - mse: 274460.8750 - val_loss: 311236.1562 - val_mse: 311236.1562
# Epoch 12/20
# 28/28 [==============================] - 0s 3ms/step - loss: 270817.2500 - mse: 270817.2500 - val_loss: 315282.5000 - val_mse: 315282.5000
# Epoch 13/20
# 28/28 [==============================] - 0s 3ms/step - loss: 271914.8438 - mse: 271914.8438 - val_loss: 314487.3438 - val_mse: 314487.3438
# Epoch 14/20
# 28/28 [==============================] - 0s 3ms/step - loss: 272524.0312 - mse: 272524.0312 - val_loss: 313987.2812 - val_mse: 313987.2812
# Epoch 15/20
# 28/28 [==============================] - 0s 3ms/step - loss: 271483.0312 - mse: 271483.0312 - val_loss: 321452.0938 - val_mse: 321452.0938
# Epoch 16/20
# 28/28 [==============================] - 0s 3ms/step - loss: 271536.0312 - mse: 271536.0312 - val_loss: 320984.1875 - val_mse: 320984.1875
# Epoch 17/20
# 28/28 [==============================] - 0s 5ms/step - loss: 270368.0625 - mse: 270368.0625 - val_loss: 311960.4688 - val_mse: 311960.4688
# Epoch 18/20
# 28/28 [==============================] - 0s 4ms/step - loss: 271233.2812 - mse: 271233.2812 - val_loss: 312101.1250 - val_mse: 312101.1250
# Epoch 19/20
# 28/28 [==============================] - 0s 3ms/step - loss: 276346.2812 - mse: 276346.2812 - val_loss: 329462.0938 - val_mse: 329462.0938
# Epoch 20/20
# 28/28 [==============================] - 0s 4ms/step - loss: 273862.3125 - mse: 273862.3125 - val_loss: 313191.9688 - val_mse: 313191.9688
# 2/2 [==============================] - 0s 7ms/step
# 0.41661023964727656

# %%
GPU_Intel
# Out:
#      laptop_ID Company            Product  TypeName  Inches  \
# 0         1274    Asus  Rog G752VT-GC073T    Gaming    17.3
# 1          286    Dell      Inspiron 3567  Notebook    15.6
# 2          897    Dell        Vostro 3568  Notebook    15.6
# 3          910    Dell        Vostro 3568  Notebook    15.6
# 4          979    Dell      Inspiron 3567  Notebook    15.6
# ..         ...     ...                ...       ...     ...
# 608        471  Lenovo       Thinkpad P51  Notebook    15.6
# 609         52    Acer    Aspire A515-51G  Notebook    15.6
# 610        120    Dell      Inspiron 7570  Notebook    15.6
# 611        289    Acer    Aspire A517-51G  Notebook    15.6
# 612        521  Xiaomi        Mi Notebook  Notebook    15.6
#
#                 ScreenResolution                          Cpu  CPU_Benchmark  \
# 0    IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz           6528
# 1              Full HD 1920x1080   Intel Core i3 6006U 2.0GHz           2273
# 2                       1366x768   Intel Core i3 6006U 2.0GHz           2273
# 3                       1366x768   Intel Core i3 6006U 2.0GHz           2273
# 4                       1366x768   Intel Core i3 6006U 2.0GHz           2273
# ..                           ...                          ...            ...
# 608            Full HD 1920x1080  Intel Core i7 7820HQ 2.9GHz           7140
# 609  IPS Panel Full HD 1920x1080   Intel Core i7 8550U 1.8GHz           5951
# 610  IPS Panel Full HD 1920x1080   Intel Core i7 8550U 1.8GHz           5951
# 611  IPS Panel Full HD 1920x1080   Intel Core i7 8550U 1.8GHz           5951
# 612  IPS Panel Full HD 1920x1080   Intel Core i7 8550U 1.8GHz           5951
#
#       Ram               Memory  Memory_benchmark                     Gpu  \
# 0    16GB  128GB SSD + 1TB HDD             58.98      Intel Graphics 620
# 1     4GB              1TB HDD             39.99   Intel HD Graphics 400
# 2     4GB              1TB HDD             39.99   Intel HD Graphics 400
# 3     4GB              1TB HDD             39.99   Intel HD Graphics 400
# 4     4GB              1TB HDD             39.99   Intel HD Graphics 400
# ..    ...                  ...               ...                     ...
# 608   8GB            256GB SSD             22.99  Intel UHD Graphics 620
# 609   8GB            256GB SSD             22.99  Intel UHD Graphics 620
# 610   8GB  256GB SSD + 1TB HDD             69.98  Intel UHD Graphics 620
# 611   8GB            256GB SSD             22.99  Intel UHD Graphics 620
# 612  16GB            256GB SSD             22.99  Intel UHD Graphics 620
#
#      GPU_benchmark       OpSys  Weight  Price_euros
# 0              3.9  Windows 10   1.8kg       919.00
# 1              1.1   Chrome OS  1.25kg       389.00
# 2              1.1   Chrome OS   1.5kg       325.00
# 3              1.1       No OS  1.86kg       299.00
# 4              1.1     Android  0.69kg       549.00
# ..             ...         ...     ...          ...
# 608            4.4  Windows 10  1.56kg      1049.00
# 609            4.4  Windows 10  1.88kg      1298.00
# 610            4.4  Windows 10  1.49kg       675.00
# 611            4.4  Windows 10  1.88kg      1096.16
# 612            4.4  Windows 10  1.21kg      1649.00
#
# [613 rows x 16 columns]

# %%
GPU_Intel=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/Intel.csv")
GPU_Intel.head()
# Out:
#    laptop_ID Company            Product  TypeName  Inches  \
# 0       1274    Asus  Rog G752VT-GC073T    Gaming    17.3
# 1        286    Dell      Inspiron 3567  Notebook    15.6
# 2        897    Dell        Vostro 3568  Notebook    15.6
# 3        910    Dell        Vostro 3568  Notebook    15.6
# 4        979    Dell      Inspiron 3567  Notebook    15.6
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0  IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz           6528
# 1            Full HD 1920x1080   Intel Core i3 6006U 2.0GHz           2273
# 2                     1366x768   Intel Core i3 6006U 2.0GHz           2273
# 3                     1366x768   Intel Core i3 6006U 2.0GHz           2273
# 4                     1366x768   Intel Core i3 6006U 2.0GHz           2273
#
#     Ram               Memory  Memory_benchmark                    Gpu  \
# 0  16GB  128GB SSD + 1TB HDD             58.98     Intel Graphics 620
# 1   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 2   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 3   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 4   4GB              1TB HDD             39.99  Intel HD Graphics 400
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            3.9  Windows 10   1.8kg        919.0
# 1            1.1   Chrome OS  1.25kg        389.0
# 2            1.1   Chrome OS   1.5kg        325.0
# 3            1.1       No OS  1.86kg        299.0
# 4            1.1     Android  0.69kg        549.0

# %%
features_GPU_Intel = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_Intel, X_raw_test_GPU_Intel, Y_GPU_Intel, Y_test_GPU_Intel = train_test_split(GPU_Intel[features_GPU_Intel].values, GPU_Intel[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_Intel)
X_GPU_Intel = scaler.transform(X_raw_GPU_Intel)
X_test_GPU_Intel = scaler.transform(X_raw_test_GPU_Intel)

# formatting
Y_GPU_Intel = Y_GPU_Intel.reshape((-1, 1))
Y_test_GPU_Intel = Y_test_GPU_Intel.reshape((-1, 1))

model_GPU_Intel=Sequential([
    Dense(units=25,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=10,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_Intel.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_Intel = model_GPU_Intel.fit(
    x=X_GPU_Intel,
    y=Y_GPU_Intel,
    batch_size=8,
    epochs=20,
    validation_data=(X_test_GPU_Intel, Y_test_GPU_Intel),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_Intel, 'mse')
yhat_GPU_Intel= model_GPU_Intel.predict(X_test_GPU_Intel)

r2_GPU_Intel = np.power(yhat_GPU_Intel - np.mean(Y_test_GPU_Intel), 2).sum() / np.power(Y_test_GPU_Intel - np.mean(Y_test_GPU_Intel), 2).sum()
r2_GPU_Intel
# Out:
# Epoch 1/20
# 62/62 [==============================] - 1s 6ms/step - loss: 1324034.6250 - mse: 1324034.6250 - val_loss: 1247681.1250 - val_mse: 1247681.1250
# Epoch 2/20
# 62/62 [==============================] - 0s 2ms/step - loss: 439111.4062 - mse: 439111.4062 - val_loss: 398000.0000 - val_mse: 398000.0000
# Epoch 3/20
# 62/62 [==============================] - 0s 3ms/step - loss: 262581.5625 - mse: 262581.5625 - val_loss: 344619.5000 - val_mse: 344619.5000
# Epoch 4/20
# 62/62 [==============================] - 0s 4ms/step - loss: 256193.0938 - mse: 256193.0938 - val_loss: 349536.8750 - val_mse: 349536.8750
# Epoch 5/20
# 62/62 [==============================] - 0s 3ms/step - loss: 258600.2188 - mse: 258600.2188 - val_loss: 347329.4375 - val_mse: 347329.4375
# Epoch 6/20
# 62/62 [==============================] - 0s 3ms/step - loss: 257916.1562 - mse: 257916.1562 - val_loss: 362931.0625 - val_mse: 362931.0625
# Epoch 7/20
# 62/62 [==============================] - 0s 3ms/step - loss: 256998.5469 - mse: 256998.5469 - val_loss: 344878.0938 - val_mse: 344878.0938
# Epoch 8/20
# 62/62 [==============================] - 0s 3ms/step - loss: 265909.7812 - mse: 265909.7812 - val_loss: 362370.1250 - val_mse: 362370.1250
# Epoch 9/20
# 62/62 [==============================] - 0s 3ms/step - loss: 259285.6562 - mse: 259285.6562 - val_loss: 346718.3438 - val_mse: 346718.3438
# Epoch 10/20
# 62/62 [==============================] - 0s 2ms/step - loss: 256964.5312 - mse: 256964.5312 - val_loss: 348506.4688 - val_mse: 348506.4688
# Epoch 11/20
# 62/62 [==============================] - 0s 2ms/step - loss: 259426.6562 - mse: 259426.6562 - val_loss: 345166.8750 - val_mse: 345166.8750
# Epoch 12/20
# 62/62 [==============================] - 0s 3ms/step - loss: 257391.9375 - mse: 257391.9375 - val_loss: 357906.3750 - val_mse: 357906.3750
# Epoch 13/20
# 62/62 [==============================] - 0s 3ms/step - loss: 258370.7500 - mse: 258370.7500 - val_loss: 351179.5625 - val_mse: 351179.5625
# Epoch 14/20
# 62/62 [==============================] - 0s 3ms/step - loss: 257179.5781 - mse: 257179.5781 - val_loss: 358706.7500 - val_mse: 358706.7500
# Epoch 15/20
# 62/62 [==============================] - 0s 3ms/step - loss: 261339.6406 - mse: 261339.6406 - val_loss: 353054.4375 - val_mse: 353054.4375
# Epoch 16/20
# 62/62 [==============================] - 0s 2ms/step - loss: 256622.3281 - mse: 256622.3281 - val_loss: 347285.1562 - val_mse: 347285.1562
# Epoch 17/20
# 62/62 [==============================] - 0s 3ms/step - loss: 259620.2344 - mse: 259620.2344 - val_loss: 368161.9062 - val_mse: 368161.9062
# Epoch 18/20
# 62/62 [==============================] - 0s 3ms/step - loss: 267191.7188 - mse: 267191.7188 - val_loss: 346433.9062 - val_mse: 346433.9062
# Epoch 19/20
# 62/62 [==============================] - 0s 3ms/step - loss: 257932.6094 - mse: 257932.6094 - val_loss: 348483.7188 - val_mse: 348483.7188
# Epoch 20/20
# 62/62 [==============================] - 0s 3ms/step - loss: 256270.2969 - mse: 256270.2969 - val_loss: 343682.0312 - val_mse: 343682.0312
# 4/4 [==============================] - 0s 4ms/step
# 0.14908426770406416
