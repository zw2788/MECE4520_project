# %% [markdown]
# <a href="https://colab.research.google.com/github/zw2788/MECE4520_project/blob/main/MECE_4520_LaptopPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Linear Rregression

# %% [markdown]
# Neural Network

# %%
from typing import Tuple
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set(font_scale=1.5)
sns.set_style("whitegrid", {'grid.linestyle':'--'})

import numpy as np
import pandas as pd

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/Laptop_Intel1012.csv")
data.head()
# Out:
#    laptop_ID Company             Product            TypeName  Inches  \
# 0        739    Dell       Inspiron 3567            Notebook    15.6
# 1        898    Asus  Rog GL753VD-GC082T              Gaming    17.3
# 2         45    Dell       Inspiron 7773  2 in 1 Convertible    17.3
# 3        399    Acer            Aspire 5            Notebook    15.6
# 4        476  Lenovo      Thinkpad T460s           Ultrabook    14.0
#
#                   ScreenResolution                          Cpu  \
# 0                         1366x768   Intel Core i5 7200U 2.5GHz
# 1                Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz
# 2  Full HD / Touchscreen 1920x1080   Intel Core i5 8250U 1.6GHz
# 3               IPS Panel 1366x768   Intel Core i5 8250U 1.6GHz
# 4     IPS Panel Quad HD+ 2560x1440   Intel Core i7 6600U 2.6GHz
#
#    CPU_benchmark   Ram  Ram_benchmark               Memory  Memory_benchmark  \
# 0           3397  12GB             12              1TB HDD             39.99
# 1           5092  12GB             12  128GB SSD + 1TB HDD             58.98
# 2           5901  12GB             12              1TB HDD             39.99
# 3           5901  12GB             12              1TB HDD             39.99
# 4           3474  12GB             12            256GB SSD             22.99
#
#                       Gpu  GPU_benchmark       OpSys  Weight  \
# 0   Intel HD Graphics 520            3.5  Windows 10   2.3kg
# 1      AMD Radeon R5 M430            3.1  Windows 10  1.90kg
# 2   Intel HD Graphics 520            3.5  Windows 10  1.86kg
# 3   Intel HD Graphics 520            3.5  Windows 10   1.2kg
# 4  Intel HD Graphics 6000            3.9       macOS  1.34kg
#
#    Weight_benchmark  Price_euros
# 0              2.30       418.64
# 1              1.90       817.95
# 2              1.86       469.00
# 3              1.20      1535.00
# 4              1.34       898.94

# %%
features = [
    "GPU_benchmark",
    "Memory_benchmark",
    "CPU_benchmark",
    "Weight_benchmark",
    "Ram_benchmark"

]
label = "Price_euros"

# train test split
X_raw, X_raw_test, Y, Y_test = train_test_split(data[features].values, data[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw)
X = scaler.transform(X_raw)
X_test = scaler.transform(X_raw_test)

# formatting
Y = Y.reshape((-1, 1))
Y_test = Y_test.reshape((-1, 1))

# %%
fig = plt.figure(figsize=(16,6))
axes = fig.add_subplot(1, 1, 1)
axes.plot(X, Y, 'ro')
axes.set_xlabel('x')
axes.set_ylabel('u_ture')
axes.grid()

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam


model=Sequential([
    Dense(units=50,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=20,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history = model.fit(
    x=X,
    y=Y,
    batch_size=32,
    epochs=20,
    validation_data=(X_test, Y_test),
    verbose=1,
    shuffle=True,
)
# Out:
# Epoch 1/20
# 26/26 [==============================] - 1s 9ms/step - loss: 1722545.8750 - mse: 1722545.8750 - val_loss: 1786213.6250 - val_mse: 1786213.6250
# Epoch 2/20
# 26/26 [==============================] - 0s 4ms/step - loss: 1477786.3750 - mse: 1477786.3750 - val_loss: 1020663.6250 - val_mse: 1020663.6250
# Epoch 3/20
# 26/26 [==============================] - 0s 3ms/step - loss: 495453.5000 - mse: 495453.5000 - val_loss: 430957.7188 - val_mse: 430957.7188
# Epoch 4/20
# 26/26 [==============================] - 0s 4ms/step - loss: 267661.8750 - mse: 267661.8750 - val_loss: 268852.7812 - val_mse: 268852.7812
# Epoch 5/20
# 26/26 [==============================] - 0s 3ms/step - loss: 224980.8438 - mse: 224980.8438 - val_loss: 237880.9844 - val_mse: 237880.9844
# Epoch 6/20
# 26/26 [==============================] - 0s 4ms/step - loss: 205158.1250 - mse: 205158.1250 - val_loss: 222476.6562 - val_mse: 222476.6562
# Epoch 7/20
# 26/26 [==============================] - 0s 3ms/step - loss: 195757.6719 - mse: 195757.6719 - val_loss: 210317.5000 - val_mse: 210317.5000
# Epoch 8/20
# 26/26 [==============================] - 0s 3ms/step - loss: 191049.5469 - mse: 191049.5469 - val_loss: 204141.6406 - val_mse: 204141.6406
# Epoch 9/20
# 26/26 [==============================] - 0s 3ms/step - loss: 188258.5781 - mse: 188258.5781 - val_loss: 200633.9844 - val_mse: 200633.9844
# Epoch 10/20
# 26/26 [==============================] - 0s 3ms/step - loss: 185985.0312 - mse: 185985.0312 - val_loss: 196594.5938 - val_mse: 196594.5938
# Epoch 11/20
# 26/26 [==============================] - 0s 3ms/step - loss: 184247.8906 - mse: 184247.8906 - val_loss: 193647.8594 - val_mse: 193647.8594
# Epoch 12/20
# 26/26 [==============================] - 0s 3ms/step - loss: 184766.0938 - mse: 184766.0938 - val_loss: 191697.0781 - val_mse: 191697.0781
# Epoch 13/20
# 26/26 [==============================] - 0s 3ms/step - loss: 182941.4219 - mse: 182941.4219 - val_loss: 195618.1094 - val_mse: 195618.1094
# Epoch 14/20
# 26/26 [==============================] - 0s 4ms/step - loss: 182392.0312 - mse: 182392.0312 - val_loss: 190088.3125 - val_mse: 190088.3125
# Epoch 15/20
# 26/26 [==============================] - 0s 4ms/step - loss: 183349.2812 - mse: 183349.2812 - val_loss: 188538.2812 - val_mse: 188538.2812
# Epoch 16/20
# 26/26 [==============================] - 0s 3ms/step - loss: 181046.3438 - mse: 181046.3438 - val_loss: 190333.4375 - val_mse: 190333.4375
# Epoch 17/20
# 26/26 [==============================] - 0s 4ms/step - loss: 183394.9688 - mse: 183394.9688 - val_loss: 189060.0781 - val_mse: 189060.0781
# Epoch 18/20
# 26/26 [==============================] - 0s 3ms/step - loss: 183118.9688 - mse: 183118.9688 - val_loss: 190028.3750 - val_mse: 190028.3750
# Epoch 19/20
# 26/26 [==============================] - 0s 3ms/step - loss: 186622.2969 - mse: 186622.2969 - val_loss: 185968.3281 - val_mse: 185968.3281
# Epoch 20/20
# 26/26 [==============================] - 0s 4ms/step - loss: 178811.0156 - mse: 178811.0156 - val_loss: 192480.7812 - val_mse: 192480.7812

# %%
def plot_history(history, key):
  plt.plot(history.history[key])
  plt.plot(history.history['val_'+key])
  plt.xlabel("Epochs")
  plt.ylabel(key)
  plt.legend([key, 'val_'+key])
  plt.show()
# Plot the history
plot_history(history, 'mse')

# %%
yhat= model.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
r2 = np.power(yhat - np.mean(Y_test), 2).sum() / np.power(Y_test - np.mean(Y_test), 2).sum()
r2
# Out:
# 0.7307096551393889

# %% [markdown]
# GPU_NV

# %%
GPU_NV=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/NV.csv")
GPU_NV.head()
# Out:
#    laptop_ID Company             Product TypeName  Inches  \
# 0        151     MSI         GE72MVR 7RG   Gaming    17.3
# 1       1232    Asus           ROG Strix   Gaming    17.3
# 2       1251     MSI       GE72VR Apache   Gaming    17.3
# 3        306    Asus  Rog GL702VS-GC095T   Gaming    17.3
# 4        584  Lenovo  IdeaPad Y910-17ISK   Gaming    17.3
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 1            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 2            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 4  IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz           6933
#
#     Ram               Memory  Memory_benchmark                   Gpu  \
# 0  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 1  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 2  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 3  16GB  256GB SSD + 1TB HDD             69.98    Nvidia GeForce 920
# 4  32GB  256GB SSD + 1TB HDD             69.98   Nvidia GeForce 920M
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            6.5  Windows 10   2.1kg      1145.00
# 1            6.5  Windows 10  2.77kg       999.00
# 2            6.5  Windows 10  2.77kg      1549.00
# 3            3.6       Linux   2.1kg       519.00
# 4            3.6  Windows 10   2.2kg       720.32

# %%
features_GPU_NV = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_NV, X_raw_test_GPU_NV, Y_GPU_NV, Y_test_GPU_NV = train_test_split(GPU_NV[features_GPU_NV].values, GPU_NV[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_NV)
X_GPU_NV = scaler.transform(X_raw_GPU_NV)
X_test_GPU_NV = scaler.transform(X_raw_test_GPU_NV)

# formatting
Y_GPU_NV = Y_GPU_NV.reshape((-1, 1))
Y_test_GPU_NV = Y_test_GPU_NV.reshape((-1, 1))

model_GPU_NV=Sequential([
    Dense(units=25,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=15,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_NV.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_NV = model_GPU_NV.fit(
    x=X_GPU_NV,
    y=Y_GPU_NV,
    batch_size=16,
    epochs=20,
    validation_data=(X_test_GPU_NV, Y_test_GPU_NV),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_NV, 'mse')
yhat_GPU_NV= model_GPU_NV.predict(X_test_GPU_NV)

r2_GPU_NV = np.power(yhat_GPU_NV - np.mean(Y_test_GPU_NV), 2).sum() / np.power(Y_test_GPU_NV - np.mean(Y_test_GPU_NV), 2).sum()
r2_GPU_NV
# Out:
# Epoch 1/20
# 14/14 [==============================] - 1s 19ms/step - loss: 2971245.0000 - mse: 2971245.0000 - val_loss: 3217013.7500 - val_mse: 3217013.7500
# Epoch 2/20
# 14/14 [==============================] - 0s 4ms/step - loss: 2967927.5000 - mse: 2967927.5000 - val_loss: 3208168.7500 - val_mse: 3208168.7500
# Epoch 3/20
# 14/14 [==============================] - 0s 5ms/step - loss: 2944196.7500 - mse: 2944196.7500 - val_loss: 3157412.7500 - val_mse: 3157412.7500
# Epoch 4/20
# 14/14 [==============================] - 0s 5ms/step - loss: 2840931.5000 - mse: 2840931.5000 - val_loss: 2962784.2500 - val_mse: 2962784.2500
# Epoch 5/20
# 14/14 [==============================] - 0s 6ms/step - loss: 2518848.0000 - mse: 2518848.0000 - val_loss: 2443654.5000 - val_mse: 2443654.5000
# Epoch 6/20
# 14/14 [==============================] - 0s 5ms/step - loss: 1829235.7500 - mse: 1829235.7500 - val_loss: 1510781.3750 - val_mse: 1510781.3750
# Epoch 7/20
# 14/14 [==============================] - 0s 4ms/step - loss: 863182.7500 - mse: 863182.7500 - val_loss: 672275.8125 - val_mse: 672275.8125
# Epoch 8/20
# 14/14 [==============================] - 0s 5ms/step - loss: 421283.9375 - mse: 421283.9375 - val_loss: 405574.9688 - val_mse: 405574.9688
# Epoch 9/20
# 14/14 [==============================] - 0s 4ms/step - loss: 294795.5000 - mse: 294795.5000 - val_loss: 317374.0000 - val_mse: 317374.0000
# Epoch 10/20
# 14/14 [==============================] - 0s 5ms/step - loss: 271936.2500 - mse: 271936.2500 - val_loss: 319053.0312 - val_mse: 319053.0312
# Epoch 11/20
# 14/14 [==============================] - 0s 5ms/step - loss: 270644.6562 - mse: 270644.6562 - val_loss: 312064.9688 - val_mse: 312064.9688
# Epoch 12/20
# 14/14 [==============================] - 0s 4ms/step - loss: 268915.5312 - mse: 268915.5312 - val_loss: 316320.6250 - val_mse: 316320.6250
# Epoch 13/20
# 14/14 [==============================] - 0s 5ms/step - loss: 268991.3125 - mse: 268991.3125 - val_loss: 317912.3750 - val_mse: 317912.3750
# Epoch 14/20
# 14/14 [==============================] - 0s 5ms/step - loss: 272835.7188 - mse: 272835.7188 - val_loss: 323642.5312 - val_mse: 323642.5312
# Epoch 15/20
# 14/14 [==============================] - 0s 4ms/step - loss: 270775.3125 - mse: 270775.3125 - val_loss: 315141.5000 - val_mse: 315141.5000
# Epoch 16/20
# 14/14 [==============================] - 0s 4ms/step - loss: 269295.8750 - mse: 269295.8750 - val_loss: 317546.5938 - val_mse: 317546.5938
# Epoch 17/20
# 14/14 [==============================] - 0s 4ms/step - loss: 270011.8750 - mse: 270011.8750 - val_loss: 310545.3750 - val_mse: 310545.3750
# Epoch 18/20
# 14/14 [==============================] - 0s 4ms/step - loss: 268473.8438 - mse: 268473.8438 - val_loss: 317593.5312 - val_mse: 317593.5312
# Epoch 19/20
# 14/14 [==============================] - 0s 4ms/step - loss: 271458.1562 - mse: 271458.1562 - val_loss: 325806.8125 - val_mse: 325806.8125
# Epoch 20/20
# 14/14 [==============================] - 0s 5ms/step - loss: 271714.0312 - mse: 271714.0312 - val_loss: 312321.3438 - val_mse: 312321.3438
# 2/2 [==============================] - 0s 7ms/step
# 0.4030627704273515

# %% [markdown]
# GPU_AMD

# %%
GPU_AMD=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/NV.csv")
GPU_AMD.head()
# Out:
#    laptop_ID Company             Product TypeName  Inches  \
# 0        151     MSI         GE72MVR 7RG   Gaming    17.3
# 1       1232    Asus           ROG Strix   Gaming    17.3
# 2       1251     MSI       GE72VR Apache   Gaming    17.3
# 3        306    Asus  Rog GL702VS-GC095T   Gaming    17.3
# 4        584  Lenovo  IdeaPad Y910-17ISK   Gaming    17.3
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 1            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 2            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz           6963
# 4  IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz           6933
#
#     Ram               Memory  Memory_benchmark                   Gpu  \
# 0  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 1  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 2  16GB  256GB SSD + 1TB HDD             69.98  Nvidia GeForce 150MX
# 3  16GB  256GB SSD + 1TB HDD             69.98    Nvidia GeForce 920
# 4  32GB  256GB SSD + 1TB HDD             69.98   Nvidia GeForce 920M
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            6.5  Windows 10   2.1kg      1145.00
# 1            6.5  Windows 10  2.77kg       999.00
# 2            6.5  Windows 10  2.77kg      1549.00
# 3            3.6       Linux   2.1kg       519.00
# 4            3.6  Windows 10   2.2kg       720.32

# %%
features_GPU_AMD = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_AMD, X_raw_test_GPU_AMD, Y_GPU_AMD, Y_test_GPU_AMD = train_test_split(GPU_AMD[features_GPU_AMD].values, GPU_AMD[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_AMD)
X_GPU_AMD = scaler.transform(X_raw_GPU_AMD)
X_test_GPU_AMD = scaler.transform(X_raw_test_GPU_AMD)

# formatting
Y_GPU_AMD = Y_GPU_AMD.reshape((-1, 1))
Y_test_GPU_AMD = Y_test_GPU_AMD.reshape((-1, 1))

model_GPU_AMD=Sequential([
    Dense(units=25,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=10,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=5,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_AMD.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_AMD = model_GPU_AMD.fit(
    x=X_GPU_AMD,
    y=Y_GPU_AMD,
    batch_size=8,
    epochs=20,
    validation_data=(X_test_GPU_AMD, Y_test_GPU_AMD),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_AMD, 'mse')
yhat_GPU_AMD= model_GPU_AMD.predict(X_test_GPU_AMD)

r2_GPU_AMD = np.power(yhat_GPU_AMD - np.mean(Y_test_GPU_AMD), 2).sum() / np.power(Y_test_GPU_AMD - np.mean(Y_test_GPU_AMD), 2).sum()
r2_GPU_AMD
# Out:
# Epoch 1/20
# 28/28 [==============================] - 1s 9ms/step - loss: 2970013.0000 - mse: 2970013.0000 - val_loss: 3210464.7500 - val_mse: 3210464.7500
# Epoch 2/20
# 28/28 [==============================] - 0s 3ms/step - loss: 2912799.5000 - mse: 2912799.5000 - val_loss: 3020979.0000 - val_mse: 3020979.0000
# Epoch 3/20
# 28/28 [==============================] - 0s 3ms/step - loss: 2376928.5000 - mse: 2376928.5000 - val_loss: 1825129.1250 - val_mse: 1825129.1250
# Epoch 4/20
# 28/28 [==============================] - 0s 3ms/step - loss: 849330.1875 - mse: 849330.1875 - val_loss: 440885.0312 - val_mse: 440885.0312
# Epoch 5/20
# 28/28 [==============================] - 0s 3ms/step - loss: 309425.6250 - mse: 309425.6250 - val_loss: 328791.7500 - val_mse: 328791.7500
# Epoch 6/20
# 28/28 [==============================] - 0s 3ms/step - loss: 278375.2500 - mse: 278375.2500 - val_loss: 313422.2188 - val_mse: 313422.2188
# Epoch 7/20
# 28/28 [==============================] - 0s 3ms/step - loss: 281300.0938 - mse: 281300.0938 - val_loss: 311293.7188 - val_mse: 311293.7188
# Epoch 8/20
# 28/28 [==============================] - 0s 4ms/step - loss: 277771.3125 - mse: 277771.3125 - val_loss: 315103.1562 - val_mse: 315103.1562
# Epoch 9/20
# 28/28 [==============================] - 0s 3ms/step - loss: 272967.4375 - mse: 272967.4375 - val_loss: 319672.4375 - val_mse: 319672.4375
# Epoch 10/20
# 28/28 [==============================] - 0s 4ms/step - loss: 272020.7812 - mse: 272020.7812 - val_loss: 310962.9375 - val_mse: 310962.9375
# Epoch 11/20
# 28/28 [==============================] - 0s 3ms/step - loss: 272672.3438 - mse: 272672.3438 - val_loss: 314399.7812 - val_mse: 314399.7812
# Epoch 12/20
# 28/28 [==============================] - 0s 3ms/step - loss: 270771.3438 - mse: 270771.3438 - val_loss: 311944.3750 - val_mse: 311944.3750
# Epoch 13/20
# 28/28 [==============================] - 0s 3ms/step - loss: 273592.5312 - mse: 273592.5312 - val_loss: 323446.9062 - val_mse: 323446.9062
# Epoch 14/20
# 28/28 [==============================] - 0s 3ms/step - loss: 284625.4688 - mse: 284625.4688 - val_loss: 310895.3750 - val_mse: 310895.3750
# Epoch 15/20
# 28/28 [==============================] - 0s 3ms/step - loss: 274949.1250 - mse: 274949.1250 - val_loss: 321829.7812 - val_mse: 321829.7812
# Epoch 16/20
# 28/28 [==============================] - 0s 3ms/step - loss: 274618.3750 - mse: 274618.3750 - val_loss: 328954.8438 - val_mse: 328954.8438
# Epoch 17/20
# 28/28 [==============================] - 0s 3ms/step - loss: 270074.0312 - mse: 270074.0312 - val_loss: 302571.3750 - val_mse: 302571.3750
# Epoch 18/20
# 28/28 [==============================] - 0s 3ms/step - loss: 270835.6250 - mse: 270835.6250 - val_loss: 317823.0625 - val_mse: 317823.0625
# Epoch 19/20
# 28/28 [==============================] - 0s 3ms/step - loss: 289770.2812 - mse: 289770.2812 - val_loss: 323125.7812 - val_mse: 323125.7812
# Epoch 20/20
# 28/28 [==============================] - 0s 3ms/step - loss: 274446.7812 - mse: 274446.7812 - val_loss: 326426.1562 - val_mse: 326426.1562
# 2/2 [==============================] - 0s 8ms/step
# 0.3785634130142824

# %%
GPU_Intel
# Out:
#      laptop_ID Company            Product  TypeName  Inches  \
# 0         1274    Asus  Rog G752VT-GC073T    Gaming    17.3
# 1          286    Dell      Inspiron 3567  Notebook    15.6
# 2          897    Dell        Vostro 3568  Notebook    15.6
# 3          910    Dell        Vostro 3568  Notebook    15.6
# 4          979    Dell      Inspiron 3567  Notebook    15.6
# ..         ...     ...                ...       ...     ...
# 608        471  Lenovo       Thinkpad P51  Notebook    15.6
# 609         52    Acer    Aspire A515-51G  Notebook    15.6
# 610        120    Dell      Inspiron 7570  Notebook    15.6
# 611        289    Acer    Aspire A517-51G  Notebook    15.6
# 612        521  Xiaomi        Mi Notebook  Notebook    15.6
#
#                 ScreenResolution                          Cpu  CPU_Benchmark  \
# 0    IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz           6528
# 1              Full HD 1920x1080   Intel Core i3 6006U 2.0GHz           2273
# 2                       1366x768   Intel Core i3 6006U 2.0GHz           2273
# 3                       1366x768   Intel Core i3 6006U 2.0GHz           2273
# 4                       1366x768   Intel Core i3 6006U 2.0GHz           2273
# ..                           ...                          ...            ...
# 608            Full HD 1920x1080  Intel Core i7 7820HQ 2.9GHz           7140
# 609  IPS Panel Full HD 1920x1080   Intel Core i7 8550U 1.8GHz           5951
# 610  IPS Panel Full HD 1920x1080   Intel Core i7 8550U 1.8GHz           5951
# 611  IPS Panel Full HD 1920x1080   Intel Core i7 8550U 1.8GHz           5951
# 612  IPS Panel Full HD 1920x1080   Intel Core i7 8550U 1.8GHz           5951
#
#       Ram               Memory  Memory_benchmark                     Gpu  \
# 0    16GB  128GB SSD + 1TB HDD             58.98      Intel Graphics 620
# 1     4GB              1TB HDD             39.99   Intel HD Graphics 400
# 2     4GB              1TB HDD             39.99   Intel HD Graphics 400
# 3     4GB              1TB HDD             39.99   Intel HD Graphics 400
# 4     4GB              1TB HDD             39.99   Intel HD Graphics 400
# ..    ...                  ...               ...                     ...
# 608   8GB            256GB SSD             22.99  Intel UHD Graphics 620
# 609   8GB            256GB SSD             22.99  Intel UHD Graphics 620
# 610   8GB  256GB SSD + 1TB HDD             69.98  Intel UHD Graphics 620
# 611   8GB            256GB SSD             22.99  Intel UHD Graphics 620
# 612  16GB            256GB SSD             22.99  Intel UHD Graphics 620
#
#      GPU_benchmark       OpSys  Weight  Price_euros
# 0              3.9  Windows 10   1.8kg       919.00
# 1              1.1   Chrome OS  1.25kg       389.00
# 2              1.1   Chrome OS   1.5kg       325.00
# 3              1.1       No OS  1.86kg       299.00
# 4              1.1     Android  0.69kg       549.00
# ..             ...         ...     ...          ...
# 608            4.4  Windows 10  1.56kg      1049.00
# 609            4.4  Windows 10  1.88kg      1298.00
# 610            4.4  Windows 10  1.49kg       675.00
# 611            4.4  Windows 10  1.88kg      1096.16
# 612            4.4  Windows 10  1.21kg      1649.00
#
# [613 rows x 16 columns]

# %%
GPU_Intel=pd.read_csv("https://raw.githubusercontent.com/zw2788/MECE4520_project/main/Intel.csv")
GPU_Intel.head()
# Out:
#    laptop_ID Company            Product  TypeName  Inches  \
# 0       1274    Asus  Rog G752VT-GC073T    Gaming    17.3
# 1        286    Dell      Inspiron 3567  Notebook    15.6
# 2        897    Dell        Vostro 3568  Notebook    15.6
# 3        910    Dell        Vostro 3568  Notebook    15.6
# 4        979    Dell      Inspiron 3567  Notebook    15.6
#
#               ScreenResolution                          Cpu  CPU_Benchmark  \
# 0  IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz           6528
# 1            Full HD 1920x1080   Intel Core i3 6006U 2.0GHz           2273
# 2                     1366x768   Intel Core i3 6006U 2.0GHz           2273
# 3                     1366x768   Intel Core i3 6006U 2.0GHz           2273
# 4                     1366x768   Intel Core i3 6006U 2.0GHz           2273
#
#     Ram               Memory  Memory_benchmark                    Gpu  \
# 0  16GB  128GB SSD + 1TB HDD             58.98     Intel Graphics 620
# 1   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 2   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 3   4GB              1TB HDD             39.99  Intel HD Graphics 400
# 4   4GB              1TB HDD             39.99  Intel HD Graphics 400
#
#    GPU_benchmark       OpSys  Weight  Price_euros
# 0            3.9  Windows 10   1.8kg        919.0
# 1            1.1   Chrome OS  1.25kg        389.0
# 2            1.1   Chrome OS   1.5kg        325.0
# 3            1.1       No OS  1.86kg        299.0
# 4            1.1     Android  0.69kg        549.0

# %%
features_GPU_Intel = [
    "GPU_benchmark",

]
label = "Price_euros"

# train test split
X_raw_GPU_Intel, X_raw_test_GPU_Intel, Y_GPU_Intel, Y_test_GPU_Intel = train_test_split(GPU_Intel[features_GPU_Intel].values, GPU_Intel[label].values, test_size=0.2, random_state=42)


# Standardize the input
scaler = StandardScaler()
scaler.fit(X_raw_GPU_Intel)
X_GPU_Intel = scaler.transform(X_raw_GPU_Intel)
X_test_GPU_Intel = scaler.transform(X_raw_test_GPU_Intel)

# formatting
Y_GPU_Intel = Y_GPU_Intel.reshape((-1, 1))
Y_test_GPU_Intel = Y_test_GPU_Intel.reshape((-1, 1))

model_GPU_Intel=Sequential([
    Dense(units=15,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=8,kernel_initializer='normal',activation='relu'),
    #Dropout(0.2),
    Dense(units=3,kernel_initializer='normal',activation='relu'),
    Dense(units=1,kernel_initializer='normal',activation='linear'),
])

model_GPU_Intel.compile(
    optimizer=Adam(learning_rate=0.01),
    loss="mse",
    metrics=["mse"])

history_GPU_Intel = model_GPU_Intel.fit(
    x=X_GPU_Intel,
    y=Y_GPU_Intel,
    batch_size=8,
    epochs=20,
    validation_data=(X_test_GPU_Intel, Y_test_GPU_Intel),
    verbose=1,
    shuffle=True,
)

plot_history(history_GPU_Intel, 'mse')
yhat_GPU_Intel= model_GPU_Intel.predict(X_test_GPU_Intel)

r2_GPU_Intel = np.power(yhat_GPU_Intel - np.mean(Y_test_GPU_Intel), 2).sum() / np.power(Y_test_GPU_Intel - np.mean(Y_test_GPU_Intel), 2).sum()
r2_GPU_Intel
# Out:
# Epoch 1/20
# 62/62 [==============================] - 1s 4ms/step - loss: 1357006.3750 - mse: 1357006.3750 - val_loss: 1472490.2500 - val_mse: 1472490.2500
# Epoch 2/20
# 62/62 [==============================] - 0s 2ms/step - loss: 753129.6250 - mse: 753129.6250 - val_loss: 472940.8750 - val_mse: 472940.8750
# Epoch 3/20
# 62/62 [==============================] - 0s 2ms/step - loss: 290549.7500 - mse: 290549.7500 - val_loss: 388772.7500 - val_mse: 388772.7500
# Epoch 4/20
# 62/62 [==============================] - 0s 2ms/step - loss: 263192.0312 - mse: 263192.0312 - val_loss: 352349.5000 - val_mse: 352349.5000
# Epoch 5/20
# 62/62 [==============================] - 0s 2ms/step - loss: 256115.6719 - mse: 256115.6719 - val_loss: 344722.3125 - val_mse: 344722.3125
# Epoch 6/20
# 62/62 [==============================] - 0s 3ms/step - loss: 259818.6562 - mse: 259818.6562 - val_loss: 345621.4062 - val_mse: 345621.4062
# Epoch 7/20
# 62/62 [==============================] - 0s 2ms/step - loss: 256390.7188 - mse: 256390.7188 - val_loss: 348192.7812 - val_mse: 348192.7812
# Epoch 8/20
# 62/62 [==============================] - 0s 2ms/step - loss: 258448.8438 - mse: 258448.8438 - val_loss: 359065.3125 - val_mse: 359065.3125
# Epoch 9/20
# 62/62 [==============================] - 0s 2ms/step - loss: 259579.0312 - mse: 259579.0312 - val_loss: 347898.2188 - val_mse: 347898.2188
# Epoch 10/20
# 62/62 [==============================] - 0s 2ms/step - loss: 256443.6562 - mse: 256443.6562 - val_loss: 345007.4688 - val_mse: 345007.4688
# Epoch 11/20
# 62/62 [==============================] - 0s 2ms/step - loss: 259763.2031 - mse: 259763.2031 - val_loss: 345135.9062 - val_mse: 345135.9062
# Epoch 12/20
# 62/62 [==============================] - 0s 3ms/step - loss: 259487.4688 - mse: 259487.4688 - val_loss: 350150.0625 - val_mse: 350150.0625
# Epoch 13/20
# 62/62 [==============================] - 0s 3ms/step - loss: 260874.0156 - mse: 260874.0156 - val_loss: 356425.3125 - val_mse: 356425.3125
# Epoch 14/20
# 62/62 [==============================] - 0s 2ms/step - loss: 257755.5938 - mse: 257755.5938 - val_loss: 352404.4375 - val_mse: 352404.4375
# Epoch 15/20
# 62/62 [==============================] - 0s 3ms/step - loss: 256994.0156 - mse: 256994.0156 - val_loss: 347644.8125 - val_mse: 347644.8125
# Epoch 16/20
# 62/62 [==============================] - 0s 2ms/step - loss: 258957.7031 - mse: 258957.7031 - val_loss: 351561.7500 - val_mse: 351561.7500
# Epoch 17/20
# 62/62 [==============================] - 0s 2ms/step - loss: 256723.5469 - mse: 256723.5469 - val_loss: 346579.0938 - val_mse: 346579.0938
# Epoch 18/20
#  1/62 [..............................] - ETA: 0s - loss: 390551.5625 - mse: 390551.5625
